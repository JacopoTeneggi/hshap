# %% [markdown]
# <a href="https://colab.research.google.com/github/lustea0201/Interpretability/blob/master/HDattempt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.manual_seed(0)
dtype = torch.float
from google.colab import drive
drive.mount('/content/drive/')
import zipfile
import sys
sys.path.append('local_modules')
# !wget https://raw.githubusercontent.com/lustea0201/Interpretability/master/utils.py -P local_modules -nc
import local_modules.utils as utils
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# File ‘local_modules/utils.py’ already there; not retrieving.

# %%
import numpy as np
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize
from torchvision.datasets import ImageFolder
import os
from torch.utils.data import DataLoader

net = utils.Net() # Model instantiation
# Loading the trained dictionnary state
net.load_state_dict(torch.load('drive/My Drive/Interpretability/model2.pth')) 

data = zipfile.ZipFile("/content/drive/My Drive/Interpretability/HD/data2/data.zip", 'r')

root_dir = "main_dir"
data.extractall(root_dir)
data.close()

Batch_Size = 20

MEAN, STD = np.array([0.5, 0.5, 0.5]), np.array([0.5, 0.5, 0.5])

transf = transforms.Compose( [ToTensor(), Normalize(mean=MEAN, std=STD)])

train_data = ImageFolder(root = os.path.join(root_dir, 'train'), transform = transf)
dataloader = DataLoader(train_data, batch_size = Batch_Size, shuffle = True, num_workers = 0)
train_loader = iter(dataloader)
X,y = next(train_loader)

# %%
class HD_Net(utils.Net): 
  def __init__(self):
    super().__init__()
  def forward(self, X):
    batch_size = len(X)
    final_output = torch.empty(batch_size, 2)
    
    max_score_1 = -1e9*torch.ones(batch_size)
    for i in range(19): 
      for j in range(19): 
        s_image = X[:,:,i*50:i*50+100, j*60:j*60+120]
        input_ = s_image.reshape(-1, 3, 100, 120) # This shape is necessary for the network 
        output = net(input_)
        _, predicted = torch.max(output.data, 1)
        
        
        score_class_1 = output.data[:,1]
        greater = (score_class_1 > max_score_1)
        max_score_1[greater] = score_class_1[greater]
        final_output[greater] = output[greater]
    return final_output

HDN = HD_Net()
correct = 0

output = HDN(X)
_, predicted = torch.max(output.data, 1)
  
print("Correct: %f percent." % (100*(predicted == y).sum()/len(y)))
# Out:
# Correct: 100.000000 percent.

# %%
i = 19
image0 = X[i]
label0 = y[i]

input0 = X[i].unsqueeze(0)
output0 = HDN(input0)
_, predicted0 = torch.max(output0.data, 1)
print(predicted0)



img0 = utils.input2image(image0, MEAN, STD)
utils.display_image(img0, label0.numpy(), int(predicted0), figure_size = (16,12))
# Out:
# tensor(-3.6712) tensor(-1.0000e+09)
# tensor(-4.8271) tensor(-3.6712)
# tensor(-5.1757) tensor(-3.6712)
# tensor(-3.9611) tensor(-3.6712)
# tensor(-6.5893) tensor(-3.6712)
# tensor(-4.8889) tensor(-3.6712)
# tensor(-6.0776) tensor(-3.6712)
# tensor(-6.1938) tensor(-3.6712)
# tensor(-5.0632) tensor(-3.6712)
# tensor(-4.6497) tensor(-3.6712)
# tensor(-4.5617) tensor(-3.6712)
# tensor(-6.8280) tensor(-3.6712)
# tensor(-7.4661) tensor(-3.6712)
# tensor(-5.2670) tensor(-3.6712)
# tensor(-4.4352) tensor(-3.6712)
# tensor(-5.4919) tensor(-3.6712)
# tensor(-4.8728) tensor(-3.6712)
# tensor(-7.8109) tensor(-3.6712)
# tensor(-5.5265) tensor(-3.6712)
# tensor(-7.0508) tensor(-3.6712)
# tensor(-3.7612) tensor(-3.6712)
# tensor(-6.8681) tensor(-3.6712)
# tensor(5.5920) tensor(-3.6712)
# tensor(5.2079) tensor(5.5920)
# tensor(-4.0930) tensor(5.5920)
# tensor(-4.5272) tensor(5.5920)
# tensor(-6.6145) tensor(5.5920)
# tensor(-6.6570) tensor(5.5920)
# tensor(-5.0656) tensor(5.5920)
# tensor(-3.4772) tensor(5.5920)
# tensor(-7.1316) tensor(5.5920)
# tensor(-4.3011) tensor(5.5920)
# tensor(-6.7391) tensor(5.5920)
# tensor(-5.4493) tensor(5.5920)
# tensor(-4.2748) tensor(5.5920)
# tensor(-7.5612) tensor(5.5920)
# tensor(-2.8914) tensor(5.5920)
# tensor(-4.3939) tensor(5.5920)
# tensor(-2.9090) tensor(5.5920)
# tensor(-8.4786) tensor(5.5920)
# tensor(-5.9239) tensor(5.5920)
# tensor(8.3666) tensor(5.5920)
# tensor(7.8975) tensor(8.3666)
# tensor(-5.4471) tensor(8.3666)
# tensor(-6.9226) tensor(8.3666)
# tensor(-6.2497) tensor(8.3666)
# tensor(-7.6299) tensor(8.3666)
# tensor(-6.3449) tensor(8.3666)
# tensor(-5.3933) tensor(8.3666)
# tensor(-4.8926) tensor(8.3666)
# tensor(-3.5677) tensor(8.3666)
# tensor(-3.0059) tensor(8.3666)
# tensor(-7.7336) tensor(8.3666)
# tensor(-4.1696) tensor(8.3666)
# tensor(-7.4081) tensor(8.3666)
# tensor(-5.1772) tensor(8.3666)
# tensor(-3.9198) tensor(8.3666)
# tensor(-6.8934) tensor(8.3666)
# tensor(-6.4070) tensor(8.3666)
# tensor(-2.8789) tensor(8.3666)
# tensor(-4.6133) tensor(8.3666)
# tensor(-4.2404) tensor(8.3666)
# tensor(-5.2625) tensor(8.3666)
# tensor(-6.9875) tensor(8.3666)
# tensor(-4.3895) tensor(8.3666)
# tensor(-3.8536) tensor(8.3666)
# tensor(-5.0669) tensor(8.3666)
# tensor(-3.0421) tensor(8.3666)
# tensor(-6.4966) tensor(8.3666)
# tensor(-6.1973) tensor(8.3666)
# tensor(-9.2482) tensor(8.3666)
# tensor(-5.0607) tensor(8.3666)
# tensor(-4.6676) tensor(8.3666)
# tensor(-5.8507) tensor(8.3666)
# tensor(-5.5518) tensor(8.3666)
# tensor(-3.1187) tensor(8.3666)
# tensor(-6.2580) tensor(8.3666)
# tensor(-3.6990) tensor(8.3666)
# tensor(-5.7687) tensor(8.3666)
# tensor(-2.4885) tensor(8.3666)
# tensor(-7.1640) tensor(8.3666)
# tensor(-10.6008) tensor(8.3666)
# tensor(-6.2650) tensor(8.3666)
# tensor(-3.8284) tensor(8.3666)
# tensor(-3.7402) tensor(8.3666)
# tensor(-4.9380) tensor(8.3666)
# tensor(-5.6792) tensor(8.3666)
# tensor(-6.0454) tensor(8.3666)
# tensor(-4.3363) tensor(8.3666)
# tensor(-6.7419) tensor(8.3666)
# tensor(-5.0264) tensor(8.3666)
# tensor(-5.4491) tensor(8.3666)
# tensor(-7.8293) tensor(8.3666)
# tensor(-6.4115) tensor(8.3666)
# tensor(-4.2114) tensor(8.3666)
# tensor(-4.7057) tensor(8.3666)
# tensor(-5.1779) tensor(8.3666)
# tensor(-5.4999) tensor(8.3666)
# tensor(-4.9054) tensor(8.3666)
# tensor(-5.3923) tensor(8.3666)
# tensor(-3.7637) tensor(8.3666)
# tensor(-5.5343) tensor(8.3666)
# tensor(-3.0648) tensor(8.3666)
# tensor(-5.6042) tensor(8.3666)
# tensor(-4.5412) tensor(8.3666)
# tensor(-3.3551) tensor(8.3666)
# tensor(-4.8149) tensor(8.3666)
# tensor(-5.1997) tensor(8.3666)
# tensor(-7.2762) tensor(8.3666)
# tensor(-4.5026) tensor(8.3666)
# tensor(-2.9600) tensor(8.3666)
# tensor(-2.9247) tensor(8.3666)
# tensor(-4.2002) tensor(8.3666)
# tensor(-6.0525) tensor(8.3666)
# tensor(-4.7774) tensor(8.3666)
# tensor(-6.2392) tensor(8.3666)
# tensor(-3.6099) tensor(8.3666)
# tensor(-5.2217) tensor(8.3666)
# tensor(-6.4712) tensor(8.3666)
# tensor(-4.8084) tensor(8.3666)
# tensor(-3.4117) tensor(8.3666)
# tensor(-4.7798) tensor(8.3666)
# tensor(-5.9270) tensor(8.3666)
# tensor(-8.1599) tensor(8.3666)
# tensor(-5.3985) tensor(8.3666)
# tensor(-4.2121) tensor(8.3666)
# tensor(-6.1025) tensor(8.3666)
# tensor(-4.8831) tensor(8.3666)
# tensor(-2.9374) tensor(8.3666)
# tensor(-5.1254) tensor(8.3666)
# tensor(-3.4377) tensor(8.3666)
# tensor(-3.8687) tensor(8.3666)
# tensor(-5.9781) tensor(8.3666)
# tensor(-6.6794) tensor(8.3666)
# tensor(-5.1935) tensor(8.3666)
# tensor(-6.2197) tensor(8.3666)
# tensor(-6.9373) tensor(8.3666)
# tensor(-7.6958) tensor(8.3666)
# tensor(-3.5253) tensor(8.3666)
# tensor(-7.0098) tensor(8.3666)
# tensor(-6.3007) tensor(8.3666)
# tensor(-6.1688) tensor(8.3666)
# tensor(-3.5498) tensor(8.3666)
# tensor(-4.4994) tensor(8.3666)
# tensor(-7.6637) tensor(8.3666)
# tensor(-5.7452) tensor(8.3666)
# tensor(-5.6491) tensor(8.3666)
# tensor(-6.8187) tensor(8.3666)
# tensor(-8.0326) tensor(8.3666)
# tensor(-6.0688) tensor(8.3666)
# tensor(-5.4815) tensor(8.3666)
# tensor(-4.0912) tensor(8.3666)
# tensor(-7.3118) tensor(8.3666)
# tensor(-3.6653) tensor(8.3666)
# tensor(-4.3683) tensor(8.3666)
# tensor(-3.4805) tensor(8.3666)
# tensor(-6.8622) tensor(8.3666)
# tensor(-3.2466) tensor(8.3666)
# tensor(-3.0449) tensor(8.3666)
# tensor(-3.4568) tensor(8.3666)
# tensor(-4.9833) tensor(8.3666)
# tensor(-3.1714) tensor(8.3666)
# tensor(-7.1383) tensor(8.3666)
# tensor(-5.3796) tensor(8.3666)
# tensor(-3.4483) tensor(8.3666)
# tensor(-5.2850) tensor(8.3666)
# tensor(-4.6127) tensor(8.3666)
# tensor(-4.5408) tensor(8.3666)
# tensor(-4.9726) tensor(8.3666)
# tensor(-3.2156) tensor(8.3666)
# tensor(-5.1238) tensor(8.3666)
# tensor(-4.6758) tensor(8.3666)
# tensor(-5.0910) tensor(8.3666)
# tensor(-6.5881) tensor(8.3666)
# tensor(-5.3890) tensor(8.3666)
# tensor(-4.9668) tensor(8.3666)
# tensor(-6.0686) tensor(8.3666)
# tensor(-8.8122) tensor(8.3666)
# tensor(-4.5132) tensor(8.3666)
# tensor(-6.6083) tensor(8.3666)
# tensor(-6.7688) tensor(8.3666)
# tensor(-5.2855) tensor(8.3666)
# tensor(-4.0653) tensor(8.3666)
# tensor(-5.3202) tensor(8.3666)
# tensor(-4.5186) tensor(8.3666)
# tensor(-3.3985) tensor(8.3666)
# tensor(-4.9749) tensor(8.3666)
# tensor(-4.0127) tensor(8.3666)
# tensor(-3.3833) tensor(8.3666)
# tensor(-3.6569) tensor(8.3666)
# tensor(-7.4115) tensor(8.3666)
# tensor(-4.7071) tensor(8.3666)
# tensor(-3.6902) tensor(8.3666)
# tensor(-5.7572) tensor(8.3666)
# tensor(-5.4416) tensor(8.3666)
# tensor(-4.0226) tensor(8.3666)
# tensor(-5.9250) tensor(8.3666)
# tensor(-2.0910) tensor(8.3666)
# tensor(-6.1813) tensor(8.3666)
# tensor(-4.4742) tensor(8.3666)
# tensor(-4.4981) tensor(8.3666)
# tensor(-8.9035) tensor(8.3666)
# tensor(-3.8221) tensor(8.3666)
# tensor(-3.6291) tensor(8.3666)
# tensor(-5.1075) tensor(8.3666)
# tensor(-6.5079) tensor(8.3666)
# tensor(-6.9624) tensor(8.3666)
# tensor(21.7316) tensor(8.3666)
# tensor(12.4960) tensor(21.7316)
# tensor(-3.8016) tensor(21.7316)
# tensor(-3.0590) tensor(21.7316)
# tensor(-4.0333) tensor(21.7316)
# tensor(-3.7514) tensor(21.7316)
# tensor(-3.2836) tensor(21.7316)
# tensor(-5.1755) tensor(21.7316)
# tensor(-5.0988) tensor(21.7316)
# tensor(-5.4609) tensor(21.7316)
# tensor(-4.4513) tensor(21.7316)
# tensor(-3.1257) tensor(21.7316)
# tensor(-4.4164) tensor(21.7316)
# tensor(-3.4347) tensor(21.7316)
# tensor(-5.0263) tensor(21.7316)
# tensor(-2.8677) tensor(21.7316)
# tensor(-6.2088) tensor(21.7316)
# tensor(-6.3632) tensor(21.7316)
# tensor(-7.0405) tensor(21.7316)
# tensor(10.9062) tensor(21.7316)
# tensor(12.1511) tensor(21.7316)
# tensor(-3.4461) tensor(21.7316)
# tensor(-5.7592) tensor(21.7316)
# tensor(-5.3957) tensor(21.7316)
# tensor(-2.9905) tensor(21.7316)
# tensor(-3.7485) tensor(21.7316)
# tensor(-6.2099) tensor(21.7316)
# tensor(-6.7127) tensor(21.7316)
# tensor(-6.0058) tensor(21.7316)
# tensor(-9.1620) tensor(21.7316)
# tensor(-5.7878) tensor(21.7316)
# tensor(-5.4939) tensor(21.7316)
# tensor(-4.2894) tensor(21.7316)
# tensor(-4.5310) tensor(21.7316)
# tensor(-3.9916) tensor(21.7316)
# tensor(-5.1537) tensor(21.7316)
# tensor(-5.9004) tensor(21.7316)
# tensor(-3.2926) tensor(21.7316)
# tensor(-5.6501) tensor(21.7316)
# tensor(-6.2884) tensor(21.7316)
# tensor(-7.1249) tensor(21.7316)
# tensor(-5.9936) tensor(21.7316)
# tensor(-5.5518) tensor(21.7316)
# tensor(-5.7438) tensor(21.7316)
# tensor(-4.7970) tensor(21.7316)
# tensor(-4.1256) tensor(21.7316)
# tensor(-3.3306) tensor(21.7316)
# tensor(-6.2423) tensor(21.7316)
# tensor(-5.7244) tensor(21.7316)
# tensor(-4.3900) tensor(21.7316)
# tensor(-3.7445) tensor(21.7316)
# tensor(-4.0752) tensor(21.7316)
# tensor(-7.1426) tensor(21.7316)
# tensor(-7.2092) tensor(21.7316)
# tensor(-6.5029) tensor(21.7316)
# tensor(-6.1577) tensor(21.7316)
# tensor(-6.3683) tensor(21.7316)
# tensor(-3.0430) tensor(21.7316)
# tensor(-7.0214) tensor(21.7316)
# tensor(-5.9232) tensor(21.7316)
# tensor(-5.1712) tensor(21.7316)
# tensor(-4.6830) tensor(21.7316)
# tensor(-5.3954) tensor(21.7316)
# tensor(-3.0047) tensor(21.7316)
# tensor(-3.3982) tensor(21.7316)
# tensor(-6.7319) tensor(21.7316)
# tensor(-8.2578) tensor(21.7316)
# tensor(-5.1370) tensor(21.7316)
# tensor(-5.4868) tensor(21.7316)
# tensor(-5.1187) tensor(21.7316)
# tensor(-5.1785) tensor(21.7316)
# tensor(-3.2929) tensor(21.7316)
# tensor(-4.1045) tensor(21.7316)
# tensor(-3.0537) tensor(21.7316)
# tensor(-2.2244) tensor(21.7316)
# tensor(-5.4995) tensor(21.7316)
# tensor(-6.0725) tensor(21.7316)
# tensor(-6.2199) tensor(21.7316)
# tensor(-5.5823) tensor(21.7316)
# tensor(-7.8515) tensor(21.7316)
# tensor(-5.4198) tensor(21.7316)
# tensor(-6.0952) tensor(21.7316)
# tensor(-5.1433) tensor(21.7316)
# tensor(-4.6484) tensor(21.7316)
# tensor(-7.4661) tensor(21.7316)
# tensor(-5.3008) tensor(21.7316)
# tensor(-7.6065) tensor(21.7316)
# tensor(-7.8363) tensor(21.7316)
# tensor(-6.4646) tensor(21.7316)
# tensor(-5.0394) tensor(21.7316)
# tensor(-5.6766) tensor(21.7316)
# tensor(-6.5903) tensor(21.7316)
# tensor(-3.8680) tensor(21.7316)
# tensor(-4.8052) tensor(21.7316)
# tensor(-6.8972) tensor(21.7316)
# tensor(-5.9216) tensor(21.7316)
# tensor(-6.3285) tensor(21.7316)
# tensor(-4.3012) tensor(21.7316)
# tensor(-3.7866) tensor(21.7316)
# tensor(-3.6562) tensor(21.7316)
# tensor(-3.3983) tensor(21.7316)
# tensor(-4.3518) tensor(21.7316)
# tensor(-4.5982) tensor(21.7316)
# tensor(-8.4937) tensor(21.7316)
# tensor(-5.7875) tensor(21.7316)
# tensor(-2.0810) tensor(21.7316)
# tensor(-6.6816) tensor(21.7316)
# tensor(-4.2277) tensor(21.7316)
# tensor(-4.2370) tensor(21.7316)
# tensor(-5.5569) tensor(21.7316)
# tensor(-8.8525) tensor(21.7316)
# tensor(-6.2732) tensor(21.7316)
# tensor(-5.8597) tensor(21.7316)
# tensor(-8.1737) tensor(21.7316)
# tensor(-6.2626) tensor(21.7316)
# tensor(-6.5113) tensor(21.7316)
# tensor(-7.9844) tensor(21.7316)
# tensor(-6.1185) tensor(21.7316)
# tensor(-6.5372) tensor(21.7316)
# tensor(-3.7990) tensor(21.7316)
# tensor(-3.2028) tensor(21.7316)
# tensor(-3.7876) tensor(21.7316)
# tensor(-5.3064) tensor(21.7316)
# tensor(-5.6739) tensor(21.7316)
# tensor(-4.3129) tensor(21.7316)
# tensor(-6.2499) tensor(21.7316)
# tensor(-5.6816) tensor(21.7316)
# tensor(-6.7812) tensor(21.7316)
# tensor(-5.4234) tensor(21.7316)
# tensor(-4.6476) tensor(21.7316)
# tensor(-5.7282) tensor(21.7316)
# tensor(-3.4820) tensor(21.7316)
# tensor(-3.9892) tensor(21.7316)
# tensor(-6.8544) tensor(21.7316)
# tensor(-5.6681) tensor(21.7316)
# tensor(-4.4504) tensor(21.7316)
# tensor(-5.3309) tensor(21.7316)
# tensor(-4.0352) tensor(21.7316)
# tensor(-2.5508) tensor(21.7316)
# tensor(-4.6887) tensor(21.7316)
# tensor(-5.0846) tensor(21.7316)
# tensor(-8.3120) tensor(21.7316)
# tensor(-5.7086) tensor(21.7316)
# tensor(-6.2197) tensor(21.7316)
# tensor(-4.3235) tensor(21.7316)
# tensor(-3.6129) tensor(21.7316)
# tensor(-5.3043) tensor(21.7316)
# tensor(-3.6358) tensor(21.7316)
# tensor(-5.2037) tensor(21.7316)
# tensor(-5.9781) tensor(21.7316)
# tensor(-3.2084) tensor(21.7316)
# tensor(-7.0082) tensor(21.7316)
# tensor(-5.0361) tensor(21.7316)
# tensor(-5.5913) tensor(21.7316)
# tensor([-25.8880,  21.7316], grad_fn=<SelectBackward>)
# tensor([[-25.8880,  21.7316]], grad_fn=<IndexPutBackward>)
# tensor([1])

# %% [markdown]
# ## SHAP

# %%
# !pip install shap 
import shap

# For SHAP
bg_choice = "black" # Default: entire training set, "average", "white", "black" 
# Median would result in white 
background = X
if (bg_choice == "black"): 
  background = -torch.ones(X.shape)
elif (bg_choice == "white"): 
  background = torch.ones(X.shape)
elif (bg_choice == "average"): 
  avg = torch.mean(X, dim = 0)
  display_image(avg, 0)
e = shap.GradientExplainer(HDN, background)
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/a8/77/b504e43e21a2ba543a1ac4696718beb500cfa708af2fb57cb54ce299045c/shap-0.35.0.tar.gz (273kB)
#      |████████████████████████████████| 276kB 2.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.18.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (1.0.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.38.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->shap) (1.12.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.35.0-cp36-cp36m-linux_x86_64.whl size=394116 sha256=c553bd7f5bf6e2009b0d2c97aa70d23173df1c9d3c80195d3d76a8846723b81e
#   Stored in directory: /root/.cache/pip/wheels/e7/f7/0f/b57055080cf8894906b3bd3616d2fc2bfd0b12d5161bcb24ac
# Successfully built shap
# Installing collected packages: shap
# Successfully installed shap-0.35.0

# %%
# !pip install pytorch-gradcam
from torchvision import transforms
from torchvision.utils import make_grid, save_image

from gradcam.utils import visualize_cam
from gradcam import GradCAM, GradCAMpp

# !wget https://raw.githubusercontent.com/lustea0201/Interpretability/master/interpret11.py -P local_modules -nc
import local_modules.interpret11 as intp

intp.shap_exp(e, input0.detach(), img0)
# Out:
# Collecting pytorch-gradcam
#   Downloading https://files.pythonhosted.org/packages/e6/0a/55251f7cbea464581c6fb831813d38a41fdeb78f3dd8193522248cb98744/pytorch-gradcam-0.2.1.tar.gz (6.0MB)
#      |████████████████████████████████| 6.0MB 2.6MB/s
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from pytorch-gradcam) (4.1.2.30)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-gradcam) (1.18.2)
# Building wheels for collected packages: pytorch-gradcam
#   Building wheel for pytorch-gradcam (setup.py) ... done
#   Created wheel for pytorch-gradcam: filename=pytorch_gradcam-0.2.1-cp36-none-any.whl size=5269 sha256=2eacf43182ed9d4347994680ef187f965374b14743a45369b99e3639974f6f29
#   Stored in directory: /root/.cache/pip/wheels/e8/1e/35/d24150a078a90ce0ad093586814d4665e945466baa89907300
# Successfully built pytorch-gradcam
# Installing collected packages: pytorch-gradcam
# Successfully installed pytorch-gradcam-0.2.1
# --2020-03-31 18:11:33--  https://raw.githubusercontent.com/lustea0201/Interpretability/master/interpret11.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3229 (3.2K) [text/plain]
# Saving to: ‘local_modules/interpret11.py’
#
# interpret11.py      100%[===================>]   3.15K  --.-KB/s    in 0s
#
# 2020-03-31 18:11:33 (64.5 MB/s) - ‘local_modules/interpret11.py’ saved [3229/3229]
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %% [markdown]
# ## Hierarchical Shapley

# %%
# For Hierarchical 
# !wget https://raw.githubusercontent.com/lustea0201/Interpretability/master/Hshapley13.py -P local_modules -nc
import local_modules.Hshapley13 as HS

white_bg = torch.ones(X.shape[1:])
h = HS.HierarchicalShap(HDN, background = white_bg)
# Out:
# File ‘local_modules/Hshapley13.py’ already there; not retrieving.

# %%
h.shapMap(X[i], y[i], shapTol = [6], keepItSimple = False, debug = False)
