# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# EXTRACT HOME FOLDER
HOME = '/home/jacopo'

# INITIALIZE EXPLAINERS DICTIONARY
expmapper = {
  0: {'name': 'Grad-Explainer'},
  1: {'name': 'Deep-Explainer'},
  2: {'name': 'H-Explainer'},
  3: {'name': 'GradCAM'},
  4: {'name': 'GradCAM++'}
}
EXP_L = len(expmapper) # number of explainers

# IMPORT PREVIOUSLY COMPUTED LOR MAP
LOR = np.load(os.path.join(HOME, 'repo/hshap/data/rsna/LOR/results/_300_200_10.npy'))
exp_x = np.linspace(-1, 0, 20)
perturbation_sizes = np.sort(1.1 - 10**(exp_x))
perturbations_L = len(perturbation_sizes)
LOR_shape = LOR.shape
print(LOR.shape)

EXP_L = LOR_shape[0]
IMG_L = LOR_shape[1]
PERTURBATION_L = LOR_shape[2]
# Out:
# (5, 300, 20)

# %%
# DEFINE OUTPUT IMAGE GRID
fig = plt.figure(figsize=(20, 4))
ax = fig.subplots(1)
ax.set_xlabel('Perturbation size')
ax.set_ylabel('LOR')
ax.set_title("Average on 300 sick images from the testing dataset, 200 random training images as reference, min-size = 10px")

for exp_id in np.arange(EXP_L):
    exp_name = expmapper[exp_id]['name']
    ax.plot(perturbation_sizes, np.mean(LOR[exp_id, :, :], axis = 0), label = exp_name)
    ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-1, 0, 20)
lox = np.sort(1.1 - 10**(x))
print(x)
print(lox)
plt.scatter(lox, lox)
# Out:
# [-1.         -0.94736842 -0.89473684 -0.84210526 -0.78947368 -0.73684211
#  -0.68421053 -0.63157895 -0.57894737 -0.52631579 -0.47368421 -0.42105263
#  -0.36842105 -0.31578947 -0.26315789 -0.21052632 -0.15789474 -0.10526316
#  -0.05263158  0.        ]
# [0.1        0.21413321 0.31524003 0.4048072  0.48415179 0.55444052
#  0.61670698 0.67186676 0.72073098 0.76401817 0.80236486 0.83633491
#  0.86642785 0.89308619 0.91670193 0.93762233 0.95615501 0.9725725
#  0.98711621 1.        ]
