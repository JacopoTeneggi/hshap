# %%
#IMPORTS
from matplotlib.colors import LinearSegmentedColormap
from scipy.special import comb
from itertools import permutations
from functools import reduce
import time
import numpy as np
import torch 
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.datasets import ImageFolder
from torchvision.transforms import Resize, ToTensor, Normalize
from torchvision import transforms
import matplotlib.pyplot as plt
import zipfile
import re
import os

import shap
from gradcam.utils import visualize_cam
from gradcam import GradCAM, GradCAMpp
from hshap.src import Explainer
from hshap import utils

# %%
# EXTRACT HOME FOLDER
HOME = '/home-net/home-2/jtenegg1@jhu.edu'
# Out:
# --2020-10-06 10:38:42--  https://raw.githubusercontent.com/JacopoTeneggi/Interpretability/master/Utils/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.200.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.200.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14385 (14K) [text/plain]
# Saving to: ‘local_modules/utils.py’
#
# utils.py            100%[===================>]  14.05K  --.-KB/s    in 0.005s
#
# 2020-10-06 10:38:42 (2.96 MB/s) - ‘local_modules/utils.py’ saved [14385/14385]
#
# --2020-10-06 10:38:45--  https://raw.githubusercontent.com/JacopoTeneggi/Interpretability/master/Hierarchical%20Shapley/HShap.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.200.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.200.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8821 (8.6K) [text/plain]
# Saving to: ‘local_modules/HShap.py’
#
# HShap.py            100%[===================>]   8.61K  --.-KB/s    in 0s
#
# 2020-10-06 10:38:46 (52.6 MB/s) - ‘local_modules/HShap.py’ saved [8821/8821]
#
# Collecting shap
#   Downloading shap-0.36.0.tar.gz (319 kB)
#      |████████████████████████████████| 319 kB 6.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/jacopo/miniconda2/envs/py38/lib/python3.8/site-packages (from shap) (1.19.1)
# Requirement already satisfied: scipy in /home/jacopo/miniconda2/envs/py38/lib/python3.8/site-packages (from shap) (1.5.2)
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.2-cp38-cp38-manylinux1_x86_64.whl (6.8 MB)
#      |█████████████████▉              | 3.8 MB 17.0 MB/s eta 0:00:01

# %%
#LOAD PRE-TRAINED-NETWORK
model = utils.Net()
model.load_state_dict(torch.load(os.path.join(HOME, 'data/Jacopo/HShap/Pretrained_models/model2.pth'))) 
# model.eval() deactivates the dropout layer in the network
model.eval()

MEAN, STD = np.array([0.5, 0.5, 0.5]), np.array([0.5, 0.5, 0.5])
transf = transforms.Compose([ToTensor(), Normalize(mean=MEAN, std=STD)])

# LOAD TRAIN DATA
SYNTH_DATA_DIR = os.path.join(HOME, 'data/Jacopo/HShap/Synthetic_data/')
train_batch_size = 64
train_data = ImageFolder(root = os.path.join(SYNTH_DATA_DIR, 'train'), transform = transf)
dataloader = DataLoader(train_data, batch_size = train_batch_size, shuffle = True, num_workers = 0)
train_loader = iter(dataloader)
X, Y = next(train_loader)
# DEFINE MASK BACKGROUND WITH AVERAGE OF TRAINING SET
background = torch.mean(X, dim = 0)
background.detach()

# DEFINE HELPER FUNCTIONS FOR KERNEL-SHAP
def mask_image(zs, segmentation, image, background = None):
  if background is None:
    background = image.mean((0,1))
  out = np.zeros((zs.shape[0], image.shape[0], image.shape[1], image.shape[2]))
  for i in range(zs.shape[0]):
    out[i,:,:,:] = image
    for j in range(zs.shape[1]):
      if zs[i,j] == 0:
        out[i][segmentation == j,:] = background
  # SHIFT CHANNELS: form (1, 100, 120, 3) to (1, 3, 100, 120)
  out2 = np.zeros((zs.shape[0], image.shape[2], image.shape[0], image.shape[1]), dtype = 'd')
  for i in range(zs.shape[0]):
    for j in range(image.shape[2]):
      out2[i, j, :, :] = out[i, :, :, j]
  out2 = torch.from_numpy(out2)
  out2 = out2.type(torch.FloatTensor)
  return out2.detach()

def fill_segmentation(values, segmentation):
  out = np.zeros(segmentation.shape)
  for i in range(len(values)):
    out[segmentation == i] = values[i]
  return out

def f(z):
  return model(mask_image(z, segments, img_orig, background = 255)).detach().numpy()

# LOAD EXAMPLE IMAGES FOLDER
EXAMPLE_DIR = os.path.join(HOME, 'data/Jacopo/HShap/Examples')
ImF = ImageFolder(root = EXAMPLE_DIR, transform = transf)
ImF_names = ImF.imgs
example_batch_size = 10
exloader = DataLoader(ImF, batch_size = example_batch_size, shuffle = False, num_workers = 0)
exIter = iter(exloader)
images, labels = next(exIter)
L = len(images) # number of examples
M = 4 # number of explainers

saliency_map_store = np.zeros((M, L, 100, 120))

for i in np.arange(L):

  image = images[i]

  # DEFINE OUTPUT FIGURES
  fig = plt.figure(figsize=(20, 4))
  axes = fig.subplots(1, 7)
  # SHOW EXAMPLE IMAGE
  axes[0].imshow(utils.input2image(image, MEAN, STD))
  axes[0].set_title('Example image')

  # Extract image id
  image_name = ImF_names[i][0]
  id = int(re.search("ex(\d*).png", image_name).group(1))

  # DEFINE INPUT
  input = image.view(-1, 3, 100, 120)
  input = input.detach()

  # GRADIENT EXPLAINER
  print('Gradient Explainer:')
  gradexp = shap.GradientExplainer(model, X)
  nsamples = 200
  t0 = time.time()
  gradexp_shapley_values, gradexp_indexes = gradexp.shap_values(input, ranked_outputs = 2, nsamples = nsamples)
  tf = time.time()
  gradexp_runtime = round(tf - t0, 2)
  gradexp_saliency = gradexp_shapley_values[0][0].sum(0)
  abs_values = np.abs(gradexp_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  axes[1].imshow(gradexp_saliency, cmap='bwr', vmin = -max_val, vmax = max_val)
  axes[1].set_title('Grad-Explainer\nruntime = %.2f s' % gradexp_runtime)
  print('Execution completed in %.2f s' % (gradexp_runtime))

  # DEEP EXPLAINER
  print('Deep Explainer:')
  deepexp = shap.DeepExplainer(model, X)
  t0 = time.time()
  deepexp_shapley_values, deepexp_indexes = deepexp.shap_values(input, ranked_outputs=2)
  tf = time.time()
  deepexp_runtime = round(tf - t0, 2)
  deepexp_saliency = deepexp_shapley_values[0][0].sum(0)
  abs_values = np.abs(deepexp_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  axes[2].imshow(deepexp_saliency, cmap='bwr', vmin=-max_val, vmax=max_val)
  axes[2].set_title('Deep-Explainer\nruntime = %.2f s' % deepexp_runtime)
  print('Execution completed in %.2f s' % (deepexp_runtime))

  # KERNEL EXPLAINER
  print('Kernel Explainer:')
  from skimage.segmentation import slic
  from keras.preprocessing import image as keras_img_tools

  file = os.path.join(EXAMPLE_DIR, 'images/ex%d.png' % id)
  img = keras_img_tools.load_img(file)
  img_orig = keras_img_tools.img_to_array(img)
  # define 10x10 segments (because we know the size of a cross)
  segments = np.zeros((100, 120))
  width = 10
  height = 10
  ROW_L = int(100 / height)
  COLUMN_L = int(120 / width)

  segment_id = 0
  for segment_row_id in np.arange(ROW_L + 1):
    
    startRow = int((segment_row_id-1) * height)
    endRow = int(segment_row_id * height)

    for segment_column_id in np.arange(COLUMN_L + 1):

      startColumn = int((segment_column_id-1) * width)
      endColumn = int(segment_column_id * width)

      segments[startRow:endRow, startColumn:endColumn] = segment_id
      segment_id += 1


  kernelexp = shap.KernelExplainer(f, np.zeros((1, ROW_L * COLUMN_L)))
  t0 = time.time()
  kernelexp_shapley_values = kernelexp.shap_values(np.ones((1, ROW_L * COLUMN_L)), nsamples = 1000)
  tf = time.time()
  kernelexp_runtime = round(tf - t0, 2)

  kernelexp_saliency = fill_segmentation(kernelexp_shapley_values[1][0], segments)
  abs_values = np.abs(kernelexp_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  axes[3].imshow(kernelexp_saliency, cmap='bwr', vmin=-max_val, vmax=max_val)
  axes[3].set_title('Kernel-Explainer\nruntime = %.2f s' % kernelexp_runtime)
  print('Execution completed in %.2f s' % (deepexp_runtime))

  # H-SHAP EXPLAINER
  print('Hierarchical Explainer:')
  hexp = HShapExplainer(model, background, 4)
  threshold = .5
  label = 1
  minW = 2
  minH = 2
  t0 = time.time()
  hexp_saliency, flatnodes = hexp.explain(image, label = label, threshold = threshold, minW = minW, minH = minH)
  tf = time.time()
  hexp_runtime = round(tf - t0, 2)
  abs_values = np.abs(hexp_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  im = axes[4].imshow(hexp_saliency, cmap='bwr')
  axes[4].set_title('H-Explainer\nruntime = %.2f s' % hexp_runtime)
  
  # GRADCAM
  gradcam = GradCAM(model, model.conv2)
  print('GradCAM:')
  t0 = time.time()
  mask, _ = gradcam(input)
  tf = time.time()
  gradcam_runtime = round(tf - t0, 2)
  gradcam_saliency = mask.detach().squeeze().numpy()
  abs_values = np.abs(gradcam_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  axes[5].imshow(gradcam_saliency, cmap='bwr', vmin=-max_val, vmax=max_val)
  axes[5].set_title('GradCAM\nruntime = %.2f s' % gradcam_runtime)
  print('Execution completed in %.2f s' % (gradcam_runtime))

  # GRADCAM++
  gradcampp = GradCAMpp(model, model.conv2)
  print('GradCAM++:')
  t0 = time.time()
  maskpp, _ = gradcampp(input)
  tf = time.time()
  gradcampp_runtime = round(tf - t0, 2)
  gradcampp_saliency = maskpp.detach().squeeze().numpy()
  abs_values = np.abs(gradcampp_saliency.flatten())
  max_val = np.nanpercentile(abs_values, 99.9)
  # print saliency map
  axes[6].imshow(gradcampp_saliency, cmap='bwr', vmin=-max_val, vmax=max_val)
  axes[6].set_title('GradCAM++\nruntime = %.2f s' % gradcampp_runtime)
  print('Execution completed in %.2f s' % (gradcampp_runtime))
  
plt.show()
# Out:
# Gradient Explainer:
# Execution completed in 12.32 s
# Deep Explainer:
# Execution completed in 2.46 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.46 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [50, 100] [0 60] with score 44.2608
# Root input [50, 75] [0 30] with score 5.2356
# Root input [62, 75] [0 15] with score 4.8617
# Root input [68, 75] [7 15] with score 6.1927
# Root input [71, 75] [11 15] with score 6.1627
# Root input [71, 73] [11 13] with score 2.1598
# Root input [73, 75] [13 15] with score 3.6866
# Root input [62, 75] [15 30] with score 2.0104
# Root input [68, 75] [15 22] with score 3.5644
# Root input [71, 75] [15 18] with score 2.5921
# Root input [71, 75] [18 22] with score 1.0015
# Root input [71, 73] [18 20] with score 1.0567
# Root input [50, 75] [30 60] with score 13.5758
# Root input [50, 62] [30 45] with score 1.8728
# Root input [56, 62] [30 37] with score 0.9377
# Root input [59, 62] [30 33] with score 1.1943
# Root input [62, 75] [30 45] with score 14.9021
# Root input [62, 68] [30 37] with score 9.1479
# Root input [62, 65] [30 33] with score 0.8879
# Root input [62, 65] [33 37] with score 2.8053
# Root input [65, 68] [33 37] with score 4.5820
# Root input [62, 68] [37 45] with score 2.2164
# Root input [62, 65] [37 41] with score 2.5202
# Root input [65, 68] [37 41] with score 2.4185
# Root input [68, 75] [30 37] with score 1.5633
# Root input [68, 71] [30 33] with score 3.5890
# Root input [68, 75] [37 45] with score 0.7604
# Root input [68, 71] [37 41] with score 2.7284
# Root input [75, 100] [0 30] with score 10.7322
# Root input [75, 87] [0 15] with score 2.3504
# Root input [75, 81] [7 15] with score 4.7307
# Root input [75, 78] [11 15] with score 3.3378
# Root input [78, 81] [11 15] with score 1.3765
# Root input [75, 87] [15 30] with score 4.7849
# Root input [75, 81] [15 22] with score 7.7789
# Root input [75, 78] [15 18] with score 5.8021
# Root input [78, 81] [18 22] with score 1.4481
# Root input [87, 100] [0 15] with score 6.0988
# Root input [87, 93] [7 15] with score 1.9494
# Root input [90, 93] [7 11] with score 4.0468
# Root input [93, 100] [0 7] with score 4.1553
# Root input [93, 96] [3 7] with score 4.0917
# Root input [96, 100] [3 7] with score 1.1282
# Root input [96, 98] [5 7] with score 1.0292
# Root input [93, 100] [7 15] with score 1.9809
# Root input [93, 96] [7 11] with score 1.6770
# Root input [96, 100] [7 11] with score 1.4749
# Root input [96, 98] [7 9] with score 0.5357
# Root input [75, 100] [30 60] with score 16.2699
# Root input [75, 87] [30 45] with score 5.8272
# Root input [81, 87] [37 45] with score 5.8262
# Root input [81, 84] [41 45] with score 3.3822
# Root input [84, 87] [41 45] with score 2.4292
# Root input [75, 87] [45 60] with score 6.2369
# Root input [81, 87] [45 52] with score 6.3785
# Root input [81, 84] [45 48] with score 1.1847
# Root input [81, 84] [48 52] with score 0.9040
# Root input [84, 87] [45 48] with score 4.2928
# Root input [87, 100] [30 45] with score 3.3765
# Root input [87, 93] [37 45] with score 6.9371
# Root input [87, 90] [41 45] with score 6.9110
# Root input [87, 100] [45 60] with score 3.8057
# Root input [87, 93] [45 52] with score 7.2179
# Root input [87, 90] [45 48] with score 2.4991
# Root input [87, 90] [48 52] with score 3.8277
# Root input [87, 93] [52 60] with score 0.8283
# Root input [50, 100] [60 120] with score 33.4135
# Root input [50, 75] [60 90] with score 14.4919
# Root input [50, 62] [60 75] with score 2.2271
# Root input [56, 62] [60 67] with score 0.5395
# Root input [59, 62] [60 63] with score 1.1629
# Root input [56, 62] [67 75] with score 0.9652
# Root input [59, 62] [67 71] with score 1.7280
# Root input [50, 62] [75 90] with score 0.9787
# Root input [56, 62] [82 90] with score 1.0538
# Root input [59, 62] [82 86] with score 1.0601
# Root input [62, 75] [60 75] with score 14.6161
# Root input [62, 68] [60 67] with score 9.2378
# Root input [62, 65] [60 63] with score 0.8912
# Root input [62, 65] [63 67] with score 2.6973
# Root input [65, 68] [63 67] with score 4.5271
# Root input [62, 68] [67 75] with score 3.4724
# Root input [62, 65] [67 71] with score 3.1453
# Root input [65, 68] [67 71] with score 2.1346
# Root input [68, 75] [60 67] with score 1.3214
# Root input [68, 71] [60 63] with score 2.7840
# Root input [68, 75] [67 75] with score 1.9966
# Root input [68, 71] [67 71] with score 3.8420
# Root input [50, 75] [90 120] with score 5.7386
# Root input [62, 75] [90 105] with score 4.0037
# Root input [68, 75] [97 105] with score 5.3061
# Root input [71, 75] [101 105] with score 5.9100
# Root input [71, 73] [101 103] with score 2.0497
# Root input [73, 75] [103 105] with score 3.7451
# Root input [62, 75] [105 120] with score 1.8731
# Root input [68, 75] [105 112] with score 3.3748
# Root input [71, 75] [105 108] with score 2.1626
# Root input [71, 75] [108 112] with score 1.2349
# Root input [71, 73] [108 110] with score 3.5852
# Root input [75, 100] [90 120] with score 14.9632
# Root input [75, 87] [90 105] with score 1.1241
# Root input [75, 81] [97 105] with score 2.2042
# Root input [75, 78] [101 105] with score 2.3009
# Root input [75, 87] [105 120] with score 11.5398
# Root input [75, 81] [105 112] with score 4.9455
# Root input [75, 78] [105 108] with score 5.2014
# Root input [78, 81] [108 112] with score 2.7837
# Root input [81, 87] [105 112] with score 0.7307
# Root input [81, 84] [108 112] with score 1.5136
# Root input [81, 87] [112 120] with score 5.5204
# Root input [81, 84] [112 116] with score 2.3021
# Root input [84, 87] [112 116] with score 3.3954
# Root input [84, 87] [116 120] with score 1.1284
# Root input [87, 100] [105 120] with score 4.7715
# Root input [87, 93] [105 112] with score 2.4545
# Root input [87, 90] [108 112] with score 2.4006
# Root input [87, 93] [112 120] with score 4.6375
# Root input [87, 90] [112 116] with score 4.7557
# Root input [87, 90] [116 120] with score 1.5748
# GradCAM:
# Execution completed in 0.14 s
# GradCAM++:
# Execution completed in 0.19 s
# Gradient Explainer:
# Execution completed in 13.06 s
# Deep Explainer:
# Execution completed in 2.55 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.55 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [60 120] with score 41.2318
# Root input [0, 25] [60 90] with score 6.2433
# Root input [12, 25] [60 75] with score 6.6916
# Root input [18, 25] [60 67] with score 5.3753
# Root input [21, 25] [60 63] with score 1.7792
# Root input [21, 25] [63 67] with score 3.2202
# Root input [23, 25] [63 65] with score 2.4861
# Root input [23, 25] [65 67] with score 0.5507
# Root input [18, 25] [67 75] with score 1.7628
# Root input [21, 25] [67 71] with score 3.1067
# Root input [21, 23] [67 69] with score 0.7115
# Root input [21, 23] [69 71] with score 0.8798
# Root input [23, 25] [67 69] with score 1.5222
# Root input [0, 25] [90 120] with score 7.5907
# Root input [12, 25] [90 105] with score 4.6164
# Root input [18, 25] [97 105] with score 5.4770
# Root input [21, 25] [101 105] with score 5.4700
# Root input [21, 23] [101 103] with score 1.9151
# Root input [23, 25] [103 105] with score 3.4735
# Root input [12, 25] [105 120] with score 2.4885
# Root input [18, 25] [105 112] with score 3.4573
# Root input [21, 25] [105 108] with score 2.3726
# Root input [21, 25] [108 112] with score 1.0917
# Root input [21, 23] [108 110] with score 4.2677
# Root input [25, 50] [60 90] with score 7.6899
# Root input [25, 37] [60 75] with score 10.8692
# Root input [25, 31] [60 67] with score 6.1116
# Root input [25, 28] [63 67] with score 5.2870
# Root input [28, 31] [60 63] with score 1.4278
# Root input [25, 31] [67 75] with score 4.2399
# Root input [25, 28] [67 71] with score 2.4521
# Root input [28, 31] [67 71] with score 3.6690
# Root input [25, 50] [90 120] with score 20.8330
# Root input [25, 37] [90 105] with score 3.6809
# Root input [25, 31] [97 105] with score 3.4220
# Root input [25, 28] [101 105] with score 2.4309
# Root input [28, 31] [101 105] with score 1.0073
# Root input [25, 37] [105 120] with score 7.6632
# Root input [25, 31] [105 112] with score 10.9574
# Root input [25, 28] [105 108] with score 7.2713
# Root input [28, 31] [108 112] with score 3.6404
# Root input [37, 50] [90 105] with score 12.3662
# Root input [37, 43] [90 97] with score 2.0289
# Root input [40, 43] [90 93] with score 2.5778
# Root input [37, 43] [97 105] with score 0.8082
# Root input [40, 43] [97 101] with score 1.5929
# Root input [43, 50] [90 97] with score 8.3441
# Root input [43, 46] [93 97] with score 4.3988
# Root input [46, 50] [90 93] with score 0.9265
# Root input [46, 50] [93 97] with score 2.6075
# Root input [46, 48] [93 95] with score 2.4401
# Root input [46, 48] [95 97] with score 2.1317
# Root input [43, 50] [97 105] with score 3.8281
# Root input [43, 46] [97 101] with score 1.3686
# Root input [46, 50] [97 101] with score 5.0525
# Root input [46, 48] [97 99] with score 2.3077
# Root input [48, 50] [97 99] with score 1.1165
# Root input [48, 50] [99 101] with score 1.7362
# Root input [50, 100] [60 120] with score 21.2028
# Root input [50, 75] [90 120] with score 5.9780
# Root input [62, 75] [90 105] with score 7.6928
# Root input [68, 75] [90 97] with score 6.2189
# Root input [71, 75] [90 93] with score 2.3735
# Root input [71, 75] [93 97] with score 3.8318
# Root input [73, 75] [93 95] with score 3.2972
# Root input [73, 75] [95 97] with score 1.1681
# Root input [68, 75] [97 105] with score 1.4747
# Root input [71, 75] [97 101] with score 2.1293
# Root input [71, 73] [97 99] with score 0.8294
# Root input [71, 73] [99 101] with score 0.5146
# Root input [73, 75] [97 99] with score 0.8133
# Root input [75, 100] [90 120] with score 16.2826
# Root input [75, 87] [90 105] with score 5.4190
# Root input [75, 81] [90 97] with score 5.2280
# Root input [75, 78] [93 97] with score 5.4929
# Root input [78, 81] [90 93] with score 0.8162
# Root input [75, 81] [97 105] with score 2.7176
# Root input [75, 78] [97 101] with score 1.1140
# Root input [78, 81] [97 101] with score 2.0814
# Root input [75, 87] [105 120] with score 7.9267
# Root input [81, 87] [105 112] with score 0.8998
# Root input [81, 84] [108 112] with score 1.5136
# Root input [81, 87] [112 120] with score 6.5702
# Root input [81, 84] [112 116] with score 2.3021
# Root input [84, 87] [112 116] with score 3.3954
# Root input [84, 87] [116 120] with score 1.1284
# Root input [87, 100] [105 120] with score 4.4420
# Root input [87, 93] [105 112] with score 2.4545
# Root input [87, 90] [108 112] with score 2.4006
# Root input [87, 93] [112 120] with score 4.6375
# Root input [87, 90] [112 116] with score 4.7557
# Root input [87, 90] [116 120] with score 1.5748
# GradCAM:
# Execution completed in 0.17 s
# GradCAM++:
# Execution completed in 0.20 s
# Gradient Explainer:
# Execution completed in 13.40 s
# Deep Explainer:
# Execution completed in 2.57 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.57 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [50, 100] [0 60] with score 16.6415
# Root input [75, 100] [0 30] with score 18.0927
# Root input [75, 87] [0 15] with score 5.4117
# Root input [81, 87] [7 15] with score 4.4771
# Root input [81, 84] [11 15] with score 3.7610
# Root input [84, 87] [11 15] with score 1.5932
# Root input [75, 87] [15 30] with score 5.2410
# Root input [81, 87] [15 22] with score 5.2556
# Root input [81, 84] [15 18] with score 1.3968
# Root input [84, 87] [15 18] with score 3.3611
# Root input [87, 100] [0 15] with score 2.4698
# Root input [87, 93] [7 15] with score 5.6405
# Root input [87, 90] [11 15] with score 5.7275
# Root input [87, 100] [15 30] with score 4.2499
# Root input [87, 93] [15 22] with score 7.9642
# Root input [87, 90] [15 18] with score 3.5854
# Root input [87, 90] [18 22] with score 4.3952
# Root input [50, 100] [60 120] with score 36.8047
# Root input [50, 75] [60 90] with score 27.4313
# Root input [50, 62] [60 75] with score 13.0142
# Root input [50, 56] [60 67] with score 4.9258
# Root input [50, 53] [60 63] with score 1.5349
# Root input [53, 56] [63 67] with score 4.1865
# Root input [50, 56] [67 75] with score 3.4709
# Root input [50, 53] [71 75] with score 1.4760
# Root input [53, 56] [71 75] with score 1.7388
# Root input [56, 62] [60 67] with score 3.2537
# Root input [56, 59] [60 63] with score 0.6724
# Root input [56, 59] [63 67] with score 3.3322
# Root input [59, 62] [60 63] with score 0.7269
# Root input [56, 62] [67 75] with score 3.1829
# Root input [56, 59] [67 71] with score 2.2556
# Root input [56, 59] [71 75] with score 3.1402
# Root input [59, 62] [67 71] with score 1.3713
# Root input [59, 62] [71 75] with score 0.8525
# Root input [50, 62] [75 90] with score 5.6899
# Root input [50, 56] [75 82] with score 5.0699
# Root input [50, 53] [78 82] with score 1.2733
# Root input [53, 56] [75 78] with score 3.9973
# Root input [56, 62] [75 82] with score 5.2761
# Root input [56, 59] [75 78] with score 5.0639
# Root input [56, 59] [78 82] with score 1.1357
# Root input [59, 62] [78 82] with score 1.2459
# Root input [62, 75] [60 75] with score 6.6431
# Root input [68, 75] [60 67] with score 5.3599
# Root input [71, 75] [60 63] with score 1.7754
# Root input [71, 75] [63 67] with score 3.0356
# Root input [73, 75] [63 65] with score 1.9824
# Root input [68, 75] [67 75] with score 1.9169
# Root input [71, 75] [67 71] with score 5.7564
# Root input [71, 73] [67 69] with score 1.3290
# Root input [71, 73] [69 71] with score 1.8726
# Root input [73, 75] [67 69] with score 2.5727
# Root input [75, 100] [60 90] with score 10.9274
# Root input [75, 87] [60 75] with score 12.7781
# Root input [75, 81] [60 67] with score 7.4384
# Root input [75, 78] [63 67] with score 5.5097
# Root input [78, 81] [60 63] with score 1.1513
# Root input [75, 81] [67 75] with score 4.8448
# Root input [75, 78] [67 71] with score 3.4608
# Root input [78, 81] [67 71] with score 3.5453
# GradCAM:
# Execution completed in 0.15 s
# GradCAM++:
# Execution completed in 0.19 s
# Gradient Explainer:
# Execution completed in 13.30 s
# Deep Explainer:
# Execution completed in 2.57 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.57 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 35.0752
# Root input [0, 25] [0 30] with score 5.4815
# Root input [0, 12] [0 15] with score 7.1167
# Root input [0, 6] [0 7] with score 2.4279
# Root input [0, 3] [0 3] with score 0.7604
# Root input [3, 6] [3 7] with score 3.5901
# Root input [6, 12] [0 7] with score 1.8479
# Root input [6, 9] [3 7] with score 2.9106
# Root input [6, 12] [7 15] with score 3.1816
# Root input [6, 9] [7 11] with score 2.8065
# Root input [9, 12] [7 11] with score 2.0845
# Root input [25, 50] [0 30] with score 26.9475
# Root input [25, 37] [0 15] with score 4.2224
# Root input [31, 37] [0 7] with score 3.8554
# Root input [31, 34] [0 3] with score 0.5101
# Root input [31, 34] [3 7] with score 0.7471
# Root input [34, 37] [3 7] with score 3.5704
# Root input [31, 37] [7 15] with score 1.2681
# Root input [31, 34] [7 11] with score 3.8473
# Root input [25, 37] [15 30] with score 7.2184
# Root input [25, 31] [15 22] with score 0.8286
# Root input [28, 31] [15 18] with score 1.0248
# Root input [31, 37] [15 22] with score 0.6554
# Root input [31, 34] [18 22] with score 1.0496
# Root input [31, 37] [22 30] with score 8.5256
# Root input [31, 34] [22 26] with score 2.2339
# Root input [31, 34] [26 30] with score 1.3628
# Root input [34, 37] [22 26] with score 3.7071
# Root input [34, 37] [26 30] with score 2.0306
# Root input [37, 50] [0 15] with score 8.5271
# Root input [37, 43] [7 15] with score 3.2918
# Root input [37, 40] [7 11] with score 1.4448
# Root input [40, 43] [11 15] with score 2.3020
# Root input [43, 50] [7 15] with score 6.0356
# Root input [43, 46] [11 15] with score 3.0801
# Root input [46, 50] [11 15] with score 3.0899
# Root input [46, 48] [13 15] with score 4.2756
# Root input [48, 50] [11 13] with score 3.0299
# Root input [37, 50] [15 30] with score 9.6141
# Root input [37, 43] [15 22] with score 1.7185
# Root input [37, 40] [18 22] with score 0.5512
# Root input [40, 43] [18 22] with score 2.2829
# Root input [37, 43] [22 30] with score 3.4342
# Root input [37, 40] [22 26] with score 2.8593
# Root input [37, 40] [26 30] with score 3.5213
# Root input [43, 50] [15 22] with score 8.2417
# Root input [43, 46] [15 18] with score 5.1040
# Root input [46, 50] [15 18] with score 4.0743
# Root input [46, 50] [18 22] with score 2.2752
# Root input [48, 50] [18 20] with score 3.9988
# Root input [25, 50] [30 60] with score 7.5022
# Root input [37, 50] [45 60] with score 9.9750
# Root input [37, 43] [52 60] with score 1.3131
# Root input [40, 43] [52 56] with score 1.2636
# Root input [40, 43] [56 60] with score 1.4293
# Root input [43, 50] [52 60] with score 8.1062
# Root input [43, 46] [52 56] with score 3.0019
# Root input [43, 46] [56 60] with score 1.4477
# Root input [46, 50] [52 56] with score 1.9038
# Root input [46, 48] [52 54] with score 0.8987
# Root input [46, 48] [54 56] with score 0.9545
# Root input [48, 50] [52 54] with score 0.5650
# Root input [46, 50] [56 60] with score 2.3095
# Root input [46, 48] [56 58] with score 1.9116
# Root input [48, 50] [58 60] with score 1.2183
# Root input [0, 50] [60 120] with score 14.3452
# Root input [25, 50] [90 120] with score 17.9779
# Root input [37, 50] [90 105] with score 8.4034
# Root input [37, 43] [97 105] with score 2.4418
# Root input [40, 43] [101 105] with score 3.6589
# Root input [43, 50] [97 105] with score 5.8400
# Root input [43, 46] [101 105] with score 3.2758
# Root input [46, 50] [101 105] with score 2.6497
# Root input [46, 48] [103 105] with score 4.3050
# Root input [48, 50] [101 103] with score 1.7929
# Root input [37, 50] [105 120] with score 9.0971
# Root input [37, 43] [105 112] with score 0.8381
# Root input [43, 50] [105 112] with score 11.2825
# Root input [43, 46] [105 108] with score 4.2840
# Root input [46, 50] [105 108] with score 3.4926
# Root input [46, 50] [108 112] with score 1.5822
# Root input [48, 50] [108 110] with score 3.1139
# Root input [50, 100] [0 60] with score 21.8533
# Root input [50, 75] [30 60] with score 18.5091
# Root input [50, 62] [45 60] with score 12.2485
# Root input [50, 56] [45 52] with score 0.8011
# Root input [50, 53] [48 52] with score 1.3067
# Root input [50, 56] [52 60] with score 7.6010
# Root input [50, 53] [52 56] with score 1.2545
# Root input [50, 53] [56 60] with score 0.5688
# Root input [53, 56] [52 56] with score 3.6261
# Root input [53, 56] [56 60] with score 1.1641
# Root input [56, 62] [45 52] with score 0.6512
# Root input [59, 62] [48 52] with score 1.1489
# Root input [56, 62] [52 60] with score 6.2914
# Root input [56, 59] [52 56] with score 2.9240
# Root input [56, 59] [56 60] with score 4.3507
# Root input [59, 62] [56 60] with score 1.0040
# Root input [62, 75] [30 45] with score 5.5009
# Root input [68, 75] [30 37] with score 4.6198
# Root input [71, 75] [30 33] with score 1.4152
# Root input [71, 75] [33 37] with score 2.2855
# Root input [73, 75] [33 35] with score 2.0916
# Root input [68, 75] [37 45] with score 1.7130
# Root input [71, 75] [37 41] with score 4.1691
# Root input [71, 73] [37 39] with score 0.5672
# Root input [71, 73] [39 41] with score 1.5187
# Root input [73, 75] [37 39] with score 2.1170
# Root input [75, 100] [30 60] with score 8.6403
# Root input [75, 87] [30 45] with score 9.7950
# Root input [75, 81] [30 37] with score 5.5151
# Root input [75, 78] [33 37] with score 5.0783
# Root input [78, 81] [30 33] with score 0.8989
# Root input [75, 81] [37 45] with score 4.0883
# Root input [75, 78] [37 41] with score 2.7154
# Root input [78, 81] [37 41] with score 3.1911
# Root input [50, 100] [60 120] with score 9.5007
# Root input [75, 100] [60 90] with score 12.9658
# Root input [75, 87] [75 90] with score 9.4651
# Root input [81, 87] [82 90] with score 9.3595
# Root input [81, 84] [82 86] with score 2.1796
# Root input [81, 84] [86 90] with score 1.1914
# Root input [84, 87] [82 86] with score 3.7466
# Root input [84, 87] [86 90] with score 1.9511
# Root input [87, 100] [75 90] with score 3.2948
# Root input [87, 93] [82 90] with score 6.0557
# Root input [87, 90] [82 86] with score 2.5848
# Root input [87, 90] [86 90] with score 3.4923
# Root input [93, 100] [75 82] with score 0.9709
# GradCAM:
# Execution completed in 0.14 s
# GradCAM++:
# Execution completed in 0.19 s
# Gradient Explainer:
# Execution completed in 13.44 s
# Deep Explainer:
# Execution completed in 2.56 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.56 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 15.2388
# Root input [0, 25] [30 60] with score 19.2774
# Root input [0, 12] [30 45] with score 1.9484
# Root input [6, 12] [30 37] with score 0.9928
# Root input [9, 12] [33 37] with score 1.8377
# Root input [6, 12] [37 45] with score 0.8662
# Root input [9, 12] [41 45] with score 1.3942
# Root input [0, 12] [45 60] with score 1.5177
# Root input [6, 12] [45 52] with score 1.3452
# Root input [9, 12] [48 52] with score 1.8662
# Root input [6, 12] [52 60] with score 1.0089
# Root input [9, 12] [52 56] with score 1.7327
# Root input [12, 25] [30 45] with score 6.6435
# Root input [12, 18] [37 45] with score 8.0328
# Root input [12, 15] [41 45] with score 4.9803
# Root input [15, 18] [41 45] with score 2.1061
# Root input [12, 25] [45 60] with score 8.1586
# Root input [12, 18] [45 52] with score 10.4608
# Root input [12, 15] [45 48] with score 2.4832
# Root input [12, 15] [48 52] with score 1.1083
# Root input [15, 18] [45 48] with score 4.7633
# Root input [18, 25] [45 52] with score 1.8982
# Root input [18, 21] [48 52] with score 1.6016
# Root input [0, 50] [60 120] with score 54.1719
# Root input [0, 25] [60 90] with score 13.9578
# Root input [12, 25] [75 90] with score 18.1595
# Root input [12, 18] [82 90] with score 13.8974
# Root input [12, 15] [82 86] with score 4.9097
# Root input [12, 15] [86 90] with score 1.7063
# Root input [15, 18] [82 86] with score 3.6714
# Root input [15, 18] [86 90] with score 2.8489
# Root input [18, 25] [75 82] with score 0.7838
# Root input [18, 21] [78 82] with score 1.0515
# Root input [18, 25] [82 90] with score 3.4040
# Root input [18, 21] [82 86] with score 1.4071
# Root input [18, 21] [86 90] with score 4.0459
# Root input [0, 25] [90 120] with score 4.4025
# Root input [12, 25] [90 105] with score 7.2033
# Root input [18, 25] [90 97] with score 5.4475
# Root input [21, 25] [90 93] with score 2.0952
# Root input [21, 25] [93 97] with score 3.0164
# Root input [23, 25] [93 95] with score 2.3126
# Root input [23, 25] [95 97] with score 1.0463
# Root input [18, 25] [97 105] with score 1.6248
# Root input [21, 25] [97 101] with score 2.8755
# Root input [21, 23] [97 99] with score 1.1839
# Root input [21, 23] [99 101] with score 0.6712
# Root input [23, 25] [97 99] with score 1.0441
# Root input [25, 50] [60 90] with score 21.7148
# Root input [25, 37] [60 75] with score 5.2483
# Root input [31, 37] [67 75] with score 5.3726
# Root input [31, 34] [71 75] with score 3.3971
# Root input [34, 37] [71 75] with score 1.9610
# Root input [25, 37] [75 90] with score 5.1732
# Root input [31, 37] [75 82] with score 6.4233
# Root input [31, 34] [75 78] with score 1.6600
# Root input [31, 34] [78 82] with score 0.9638
# Root input [34, 37] [75 78] with score 3.7715
# Root input [37, 50] [60 75] with score 11.1657
# Root input [37, 43] [60 67] with score 1.7803
# Root input [40, 43] [60 63] with score 1.6403
# Root input [37, 43] [67 75] with score 2.1780
# Root input [37, 40] [71 75] with score 1.6637
# Root input [40, 43] [67 71] with score 1.0311
# Root input [43, 50] [60 67] with score 7.1271
# Root input [43, 46] [63 67] with score 3.7931
# Root input [46, 50] [60 63] with score 0.6020
# Root input [46, 50] [63 67] with score 2.0131
# Root input [46, 48] [63 65] with score 1.6819
# Root input [46, 48] [65 67] with score 2.2160
# Root input [43, 50] [67 75] with score 2.5051
# Root input [43, 46] [67 71] with score 1.6936
# Root input [46, 50] [67 71] with score 4.5822
# Root input [46, 48] [67 69] with score 2.5476
# Root input [48, 50] [67 69] with score 0.9754
# Root input [48, 50] [69 71] with score 1.8128
# Root input [37, 50] [75 90] with score 3.2890
# Root input [37, 43] [75 82] with score 6.7236
# Root input [37, 40] [75 78] with score 2.3857
# Root input [37, 40] [78 82] with score 2.9463
# Root input [25, 50] [90 120] with score 17.3337
# Root input [25, 37] [90 105] with score 7.0519
# Root input [25, 31] [90 97] with score 4.7741
# Root input [25, 28] [93 97] with score 5.0466
# Root input [28, 31] [90 93] with score 1.3782
# Root input [25, 31] [97 105] with score 3.1852
# Root input [25, 28] [97 101] with score 1.8055
# Root input [28, 31] [97 101] with score 3.3158
# Root input [37, 50] [90 105] with score 13.3702
# Root input [37, 43] [90 97] with score 2.1586
# Root input [40, 43] [90 93] with score 2.5540
# Root input [43, 50] [90 97] with score 8.2686
# Root input [43, 46] [93 97] with score 4.5296
# Root input [46, 50] [90 93] with score 1.0960
# Root input [46, 50] [93 97] with score 2.7099
# Root input [46, 48] [93 95] with score 2.6749
# Root input [46, 48] [95 97] with score 2.0592
# Root input [43, 50] [97 105] with score 2.9661
# Root input [43, 46] [97 101] with score 1.3984
# Root input [46, 50] [97 101] with score 4.3996
# Root input [46, 48] [97 99] with score 2.2972
# Root input [48, 50] [97 99] with score 1.2113
# Root input [48, 50] [99 101] with score 1.6705
# Root input [50, 100] [0 60] with score 19.9944
# Root input [50, 75] [0 30] with score 12.2365
# Root input [50, 62] [0 15] with score 6.4975
# Root input [50, 56] [7 15] with score 5.3769
# Root input [50, 53] [11 15] with score 2.0475
# Root input [53, 56] [11 15] with score 2.6401
# Root input [56, 62] [7 15] with score 2.9836
# Root input [56, 59] [11 15] with score 4.5037
# Root input [59, 62] [11 15] with score 0.8346
# Root input [50, 62] [15 30] with score 6.4976
# Root input [50, 56] [15 22] with score 4.1348
# Root input [50, 53] [18 22] with score 0.9215
# Root input [53, 56] [15 18] with score 4.7737
# Root input [56, 62] [15 22] with score 4.5780
# Root input [56, 59] [15 18] with score 4.4282
# Root input [56, 59] [18 22] with score 0.9853
# Root input [59, 62] [18 22] with score 0.9853
# Root input [50, 75] [30 60] with score 11.9143
# Root input [62, 75] [45 60] with score 13.6782
# Root input [62, 68] [52 60] with score 12.5178
# Root input [62, 65] [52 56] with score 3.9335
# Root input [62, 65] [56 60] with score 1.6514
# Root input [65, 68] [52 56] with score 3.7466
# Root input [65, 68] [56 60] with score 2.2710
# Root input [68, 75] [52 60] with score 3.1231
# Root input [68, 71] [52 56] with score 1.9555
# Root input [68, 71] [56 60] with score 3.3824
# Root input [50, 100] [60 120] with score 21.2877
# Root input [50, 75] [60 90] with score 11.0613
# Root input [62, 75] [60 75] with score 4.9504
# Root input [68, 75] [67 75] with score 6.1133
# Root input [71, 75] [71 75] with score 6.1206
# Root input [71, 73] [71 73] with score 2.2188
# Root input [73, 75] [73 75] with score 3.8281
# Root input [62, 75] [75 90] with score 3.9192
# Root input [68, 75] [75 82] with score 2.2362
# Root input [71, 75] [75 78] with score 2.1525
# Root input [71, 75] [78 82] with score 1.0104
# Root input [71, 73] [78 80] with score 3.4768
# Root input [71, 73] [80 82] with score 0.5103
# Root input [68, 75] [82 90] with score 2.5792
# Root input [71, 75] [82 86] with score 4.1128
# Root input [71, 73] [82 84] with score 1.3731
# Root input [73, 75] [82 84] with score 1.8227
# Root input [73, 75] [84 86] with score 1.4119
# Root input [71, 75] [86 90] with score 2.2162
# Root input [71, 73] [88 90] with score 1.2438
# Root input [73, 75] [86 88] with score 2.2057
# Root input [75, 100] [60 90] with score 13.8155
# Root input [75, 87] [60 75] with score 4.2117
# Root input [75, 81] [67 75] with score 3.5860
# Root input [75, 78] [71 75] with score 2.5835
# Root input [78, 81] [71 75] with score 1.0059
# Root input [75, 87] [75 90] with score 10.9294
# Root input [75, 81] [75 82] with score 8.0511
# Root input [75, 78] [75 78] with score 7.5366
# Root input [78, 81] [78 82] with score 2.8385
# Root input [75, 81] [82 90] with score 5.1596
# Root input [75, 78] [82 86] with score 3.4872
# Root input [75, 78] [86 90] with score 2.6517
# Root input [78, 81] [86 90] with score 1.5197
# GradCAM:
# Execution completed in 0.15 s
# GradCAM++:
# Execution completed in 0.20 s
# Gradient Explainer:
# Execution completed in 14.02 s
# Deep Explainer:
# Execution completed in 2.56 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.56 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 11.5195
# Root input [25, 50] [0 30] with score 14.9849
# Root input [25, 37] [0 15] with score 4.9178
# Root input [31, 37] [7 15] with score 5.6941
# Root input [31, 34] [11 15] with score 3.4783
# Root input [34, 37] [11 15] with score 2.2825
# Root input [25, 37] [15 30] with score 4.5766
# Root input [31, 37] [15 22] with score 6.9655
# Root input [31, 34] [15 18] with score 1.1480
# Root input [31, 34] [18 22] with score 1.1560
# Root input [34, 37] [15 18] with score 4.6767
# Root input [37, 50] [0 15] with score 2.2342
# Root input [37, 43] [7 15] with score 4.7534
# Root input [37, 40] [11 15] with score 4.6923
# Root input [37, 50] [15 30] with score 2.7083
# Root input [37, 43] [15 22] with score 4.7585
# Root input [37, 40] [15 18] with score 1.3046
# Root input [37, 40] [18 22] with score 2.0264
# Root input [37, 43] [22 30] with score 1.1157
# Root input [43, 50] [15 22] with score 1.0466
# Root input [43, 46] [18 22] with score 0.8740
# Root input [0, 50] [60 120] with score 21.6252
# Root input [25, 50] [60 90] with score 16.2895
# Root input [37, 50] [60 75] with score 8.8320
# Root input [37, 43] [67 75] with score 1.9581
# Root input [40, 43] [71 75] with score 2.3811
# Root input [43, 50] [67 75] with score 5.4654
# Root input [43, 46] [71 75] with score 2.7853
# Root input [46, 50] [71 75] with score 2.2704
# Root input [46, 48] [73 75] with score 4.5282
# Root input [48, 50] [71 73] with score 2.1991
# Root input [37, 50] [75 90] with score 9.6929
# Root input [37, 43] [75 82] with score 2.1077
# Root input [40, 43] [78 82] with score 1.4075
# Root input [43, 50] [75 82] with score 10.0060
# Root input [43, 46] [75 78] with score 4.9998
# Root input [46, 50] [75 78] with score 4.0213
# Root input [46, 50] [78 82] with score 2.5019
# Root input [48, 50] [78 80] with score 4.6456
# Root input [25, 50] [90 120] with score 8.5723
# Root input [25, 37] [105 120] with score 7.4948
# Root input [31, 37] [105 112] with score 1.1076
# Root input [31, 34] [108 112] with score 1.3457
# Root input [31, 37] [112 120] with score 7.6733
# Root input [31, 34] [112 116] with score 2.7471
# Root input [34, 37] [112 116] with score 3.9499
# Root input [34, 37] [116 120] with score 1.3378
# Root input [37, 50] [105 120] with score 3.2417
# Root input [37, 43] [105 112] with score 1.0576
# Root input [37, 40] [108 112] with score 2.0035
# Root input [37, 43] [112 120] with score 3.7151
# Root input [37, 40] [112 116] with score 3.0588
# Root input [37, 40] [116 120] with score 0.5008
# Root input [50, 100] [0 60] with score 15.4344
# Root input [50, 75] [0 30] with score 6.2054
# Root input [62, 75] [0 15] with score 4.6227
# Root input [68, 75] [7 15] with score 6.0811
# Root input [71, 75] [11 15] with score 3.8891
# Root input [71, 73] [11 13] with score 2.5684
# Root input [73, 75] [13 15] with score 3.5895
# Root input [62, 75] [15 30] with score 2.6926
# Root input [68, 75] [15 22] with score 4.9319
# Root input [71, 75] [15 18] with score 3.7926
# Root input [71, 75] [18 22] with score 1.1581
# Root input [71, 73] [18 20] with score 1.8996
# Root input [75, 100] [0 30] with score 6.2029
# Root input [75, 87] [0 15] with score 2.6689
# Root input [75, 81] [7 15] with score 5.2002
# Root input [75, 78] [11 15] with score 3.8979
# Root input [78, 81] [11 15] with score 0.9961
# Root input [75, 87] [15 30] with score 6.0853
# Root input [75, 81] [15 22] with score 7.5826
# Root input [75, 78] [15 18] with score 5.9523
# Root input [78, 81] [18 22] with score 1.4578
# Root input [75, 100] [30 60] with score 6.0413
# Root input [87, 100] [45 60] with score 8.8629
# Root input [87, 93] [45 52] with score 0.5168
# Root input [90, 93] [48 52] with score 0.7467
# Root input [87, 93] [52 60] with score 1.7836
# Root input [90, 93] [52 56] with score 1.2692
# Root input [90, 93] [56 60] with score 1.7920
# Root input [93, 100] [52 60] with score 6.0343
# Root input [93, 96] [52 56] with score 3.4001
# Root input [93, 96] [56 60] with score 1.9655
# Root input [96, 100] [52 56] with score 0.8087
# Root input [96, 100] [56 60] with score 0.9495
# Root input [96, 98] [56 58] with score 0.7257
# Root input [50, 100] [60 120] with score 9.7958
# Root input [50, 75] [60 90] with score 6.2120
# Root input [62, 75] [60 75] with score 5.1136
# Root input [68, 75] [67 75] with score 6.3046
# Root input [71, 75] [71 75] with score 6.0163
# Root input [71, 73] [71 73] with score 2.2333
# Root input [73, 75] [73 75] with score 4.0649
# Root input [62, 75] [75 90] with score 2.2858
# Root input [68, 75] [75 82] with score 3.7279
# Root input [71, 75] [75 78] with score 2.5931
# Root input [71, 75] [78 82] with score 1.1578
# Root input [71, 73] [78 80] with score 1.3552
# Root input [75, 100] [60 90] with score 6.5896
# Root input [75, 87] [60 75] with score 2.0691
# Root input [75, 81] [67 75] with score 3.5478
# Root input [75, 78] [71 75] with score 2.5589
# Root input [78, 81] [71 75] with score 0.9991
# Root input [75, 87] [75 90] with score 5.9631
# Root input [75, 81] [75 82] with score 7.3013
# Root input [75, 78] [75 78] with score 5.3578
# Root input [78, 81] [78 82] with score 1.5680
# GradCAM:
# Execution completed in 0.15 s
# GradCAM++:
# Execution completed in 0.19 s
# Gradient Explainer:
# Execution completed in 13.48 s
# Deep Explainer:
# Execution completed in 2.53 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.53 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 10.0861
# Root input [0, 25] [30 60] with score 6.1592
# Root input [12, 25] [30 45] with score 7.6538
# Root input [18, 25] [30 37] with score 5.6081
# Root input [21, 25] [30 33] with score 2.1684
# Root input [21, 25] [33 37] with score 3.2702
# Root input [23, 25] [33 35] with score 2.5437
# Root input [23, 25] [35 37] with score 1.2289
# Root input [18, 25] [37 45] with score 1.6476
# Root input [21, 25] [37 41] with score 2.5447
# Root input [21, 23] [37 39] with score 1.0305
# Root input [21, 23] [39 41] with score 0.5949
# Root input [23, 25] [37 39] with score 0.9685
# Root input [25, 50] [30 60] with score 5.8565
# Root input [25, 37] [30 45] with score 7.4475
# Root input [25, 31] [30 37] with score 5.5162
# Root input [25, 28] [33 37] with score 5.3983
# Root input [25, 31] [37 45] with score 3.1079
# Root input [25, 28] [37 41] with score 1.5020
# Root input [28, 31] [37 41] with score 1.9706
# Root input [0, 50] [60 120] with score 50.3328
# Root input [0, 25] [60 90] with score 6.8587
# Root input [0, 12] [60 75] with score 0.6356
# Root input [0, 12] [75 90] with score 0.6081
# Root input [6, 12] [75 82] with score 1.7492
# Root input [9, 12] [75 78] with score 1.5364
# Root input [12, 25] [75 90] with score 7.1205
# Root input [18, 25] [75 82] with score 1.2059
# Root input [21, 25] [78 82] with score 1.1890
# Root input [21, 23] [80 82] with score 1.1428
# Root input [18, 25] [82 90] with score 6.5453
# Root input [21, 25] [82 86] with score 4.1837
# Root input [21, 23] [82 84] with score 1.2831
# Root input [23, 25] [82 84] with score 1.4005
# Root input [23, 25] [84 86] with score 1.0719
# Root input [21, 25] [86 90] with score 2.6467
# Root input [21, 23] [88 90] with score 2.1841
# Root input [23, 25] [86 88] with score 4.4384
# Root input [0, 25] [90 120] with score 16.0758
# Root input [0, 12] [90 105] with score 13.1699
# Root input [0, 6] [90 97] with score 5.1379
# Root input [0, 3] [90 93] with score 1.1686
# Root input [3, 6] [93 97] with score 3.1517
# Root input [6, 12] [90 97] with score 5.7004
# Root input [6, 9] [90 93] with score 0.8632
# Root input [6, 9] [93 97] with score 2.9216
# Root input [9, 12] [90 93] with score 1.1480
# Root input [6, 12] [97 105] with score 3.9796
# Root input [6, 9] [97 101] with score 4.5330
# Root input [9, 12] [97 101] with score 2.7085
# Root input [0, 12] [105 120] with score 5.9207
# Root input [0, 6] [112 120] with score 3.3053
# Root input [0, 3] [112 116] with score 0.6774
# Root input [3, 6] [112 116] with score 3.1849
# Root input [6, 12] [105 112] with score 0.6819
# Root input [9, 12] [108 112] with score 1.8601
# Root input [6, 12] [112 120] with score 3.7379
# Root input [6, 9] [112 116] with score 3.1754
# Root input [6, 9] [116 120] with score 2.1235
# Root input [25, 50] [60 90] with score 22.1536
# Root input [25, 37] [60 75] with score 6.6611
# Root input [31, 37] [67 75] with score 6.0127
# Root input [31, 34] [71 75] with score 4.0246
# Root input [34, 37] [71 75] with score 1.9802
# Root input [25, 37] [75 90] with score 12.0984
# Root input [25, 31] [82 90] with score 6.4654
# Root input [25, 28] [82 86] with score 4.6473
# Root input [25, 28] [86 90] with score 3.5488
# Root input [28, 31] [82 86] with score 0.7626
# Root input [28, 31] [86 90] with score 2.5375
# Root input [31, 37] [75 82] with score 4.7191
# Root input [31, 34] [75 78] with score 1.5647
# Root input [31, 34] [78 82] with score 0.8952
# Root input [34, 37] [75 78] with score 3.6320
# Root input [37, 50] [60 75] with score 3.1756
# Root input [37, 43] [67 75] with score 6.6302
# Root input [37, 40] [71 75] with score 6.6177
# Root input [37, 50] [75 90] with score 3.8498
# Root input [37, 43] [75 82] with score 7.7407
# Root input [37, 40] [75 78] with score 3.9142
# Root input [37, 40] [78 82] with score 3.8351
# Root input [25, 50] [90 120] with score 7.0491
# Root input [25, 37] [105 120] with score 6.8068
# Root input [31, 37] [105 112] with score 0.8737
# Root input [31, 34] [108 112] with score 1.4121
# Root input [31, 37] [112 120] with score 7.3433
# Root input [31, 34] [112 116] with score 2.9763
# Root input [34, 37] [112 116] with score 3.6221
# Root input [34, 37] [116 120] with score 1.2966
# Root input [37, 50] [105 120] with score 2.9235
# Root input [37, 43] [105 112] with score 0.9228
# Root input [37, 40] [108 112] with score 1.6725
# Root input [37, 43] [112 120] with score 3.0671
# Root input [37, 40] [112 116] with score 2.1601
# Root input [37, 40] [116 120] with score 0.7272
# GradCAM:
# Execution completed in 0.14 s
# GradCAM++:
# Execution completed in 0.19 s
# Gradient Explainer:
# Execution completed in 13.49 s
# Deep Explainer:
# Execution completed in 2.55 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.55 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 19.5522
# Root input [0, 25] [0 30] with score 4.8923
# Root input [0, 12] [15 30] with score 1.6023
# Root input [6, 12] [22 30] with score 0.9883
# Root input [9, 12] [22 26] with score 0.9735
# Root input [12, 25] [0 15] with score 4.5396
# Root input [18, 25] [7 15] with score 5.9519
# Root input [21, 25] [11 15] with score 5.9360
# Root input [21, 23] [11 13] with score 2.0435
# Root input [23, 25] [13 15] with score 3.8300
# Root input [12, 25] [15 30] with score 1.5175
# Root input [18, 25] [15 22] with score 4.1471
# Root input [21, 25] [15 18] with score 2.6746
# Root input [25, 50] [0 30] with score 5.0807
# Root input [25, 37] [0 15] with score 3.1909
# Root input [25, 31] [7 15] with score 5.5328
# Root input [25, 28] [11 15] with score 4.0048
# Root input [28, 31] [11 15] with score 1.5459
# Root input [25, 37] [15 30] with score 4.2959
# Root input [25, 31] [15 22] with score 5.9725
# Root input [25, 28] [15 18] with score 4.5940
# Root input [28, 31] [18 22] with score 1.2532
# Root input [25, 50] [30 60] with score 13.1714
# Root input [37, 50] [45 60] with score 16.2130
# Root input [37, 43] [45 52] with score 0.9031
# Root input [40, 43] [48 52] with score 1.2012
# Root input [37, 43] [52 60] with score 2.9230
# Root input [40, 43] [52 56] with score 1.1141
# Root input [40, 43] [56 60] with score 1.2902
# Root input [43, 50] [45 52] with score 0.7428
# Root input [46, 50] [48 52] with score 1.3358
# Root input [48, 50] [50 52] with score 1.3903
# Root input [43, 50] [52 60] with score 11.3106
# Root input [43, 46] [52 56] with score 4.7278
# Root input [43, 46] [56 60] with score 2.0523
# Root input [46, 50] [52 56] with score 2.7236
# Root input [46, 48] [52 54] with score 1.7675
# Root input [46, 48] [54 56] with score 1.4729
# Root input [48, 50] [52 54] with score 0.7315
# Root input [46, 50] [56 60] with score 4.0059
# Root input [46, 48] [56 58] with score 4.5487
# Root input [48, 50] [58 60] with score 2.5845
# Root input [0, 50] [60 120] with score 15.2781
# Root input [25, 50] [60 90] with score 8.7787
# Root input [25, 37] [60 75] with score 7.2736
# Root input [31, 37] [60 67] with score 6.6232
# Root input [31, 34] [60 63] with score 1.1376
# Root input [31, 34] [63 67] with score 1.0370
# Root input [34, 37] [63 67] with score 4.6351
# Root input [31, 37] [67 75] with score 1.6901
# Root input [31, 34] [67 71] with score 2.3777
# Root input [37, 50] [60 75] with score 3.3747
# Root input [37, 43] [60 67] with score 2.4629
# Root input [37, 40] [60 63] with score 1.7817
# Root input [37, 40] [63 67] with score 1.1124
# Root input [37, 43] [67 75] with score 2.5564
# Root input [37, 40] [67 71] with score 2.6854
# Root input [25, 50] [90 120] with score 10.7041
# Root input [25, 37] [105 120] with score 8.6719
# Root input [31, 37] [105 112] with score 1.2305
# Root input [31, 34] [108 112] with score 1.5288
# Root input [31, 37] [112 120] with score 6.7999
# Root input [31, 34] [112 116] with score 2.8423
# Root input [34, 37] [112 116] with score 3.0524
# Root input [34, 37] [116 120] with score 1.0584
# Root input [37, 50] [105 120] with score 4.0141
# Root input [37, 43] [105 112] with score 1.7148
# Root input [37, 40] [108 112] with score 1.2984
# Root input [37, 43] [112 120] with score 3.7206
# Root input [37, 40] [112 116] with score 2.3446
# Root input [37, 40] [116 120] with score 1.8696
# Root input [50, 100] [0 60] with score 26.7894
# Root input [50, 75] [0 30] with score 12.3811
# Root input [50, 62] [15 30] with score 16.3456
# Root input [50, 56] [15 22] with score 0.7127
# Root input [50, 53] [15 18] with score 0.8806
# Root input [50, 53] [18 22] with score 0.9821
# Root input [50, 56] [22 30] with score 8.0488
# Root input [50, 53] [22 26] with score 1.2795
# Root input [50, 53] [26 30] with score 0.6071
# Root input [53, 56] [22 26] with score 3.7234
# Root input [53, 56] [26 30] with score 1.2035
# Root input [56, 62] [22 30] with score 6.6621
# Root input [56, 59] [22 26] with score 3.1230
# Root input [56, 59] [26 30] with score 4.4772
# Root input [59, 62] [26 30] with score 1.1383
# Root input [50, 75] [30 60] with score 8.2072
# Root input [62, 75] [30 45] with score 12.5920
# Root input [62, 68] [30 37] with score 7.6390
# Root input [62, 65] [30 33] with score 0.7537
# Root input [62, 65] [33 37] with score 2.8817
# Root input [65, 68] [33 37] with score 3.9178
# Root input [62, 68] [37 45] with score 2.2989
# Root input [62, 65] [37 41] with score 1.7510
# Root input [65, 68] [37 41] with score 1.9210
# Root input [68, 75] [30 37] with score 0.8866
# Root input [68, 71] [30 33] with score 1.4786
# Root input [68, 75] [37 45] with score 1.4946
# Root input [68, 71] [37 41] with score 2.3911
# Root input [75, 100] [30 60] with score 9.5918
# Root input [75, 87] [30 45] with score 7.9941
# Root input [81, 87] [30 37] with score 7.5413
# Root input [81, 84] [30 33] with score 1.2056
# Root input [81, 84] [33 37] with score 1.1068
# Root input [84, 87] [33 37] with score 5.3375
# Root input [81, 87] [37 45] with score 1.5112
# Root input [81, 84] [37 41] with score 2.1249
# Root input [87, 100] [30 45] with score 4.4801
# Root input [87, 93] [30 37] with score 3.5919
# Root input [87, 90] [30 33] with score 2.9601
# Root input [87, 90] [33 37] with score 1.5821
# Root input [87, 93] [37 45] with score 2.7213
# Root input [87, 90] [37 41] with score 3.5525
# Root input [50, 100] [60 120] with score 38.0485
# Root input [50, 75] [90 120] with score 22.0450
# Root input [50, 62] [90 105] with score 0.9688
# Root input [56, 62] [97 105] with score 0.9357
# Root input [59, 62] [101 105] with score 0.9490
# Root input [50, 62] [105 120] with score 0.6946
# Root input [56, 62] [105 112] with score 1.2013
# Root input [59, 62] [108 112] with score 1.2872
# Root input [62, 75] [90 105] with score 7.9957
# Root input [62, 68] [97 105] with score 7.2615
# Root input [62, 65] [101 105] with score 5.4952
# Root input [65, 68] [101 105] with score 2.3627
# Root input [68, 75] [97 105] with score 2.5089
# Root input [68, 71] [101 105] with score 0.7014
# Root input [71, 75] [101 105] with score 4.4639
# Root input [71, 73] [101 103] with score 2.2682
# Root input [73, 75] [103 105] with score 3.5960
# Root input [62, 75] [105 120] with score 11.3354
# Root input [62, 68] [105 112] with score 8.0679
# Root input [62, 65] [105 108] with score 2.2761
# Root input [62, 65] [108 112] with score 0.9256
# Root input [65, 68] [105 108] with score 6.3238
# Root input [68, 75] [105 112] with score 3.1651
# Root input [68, 71] [108 112] with score 1.4699
# Root input [71, 75] [105 108] with score 1.9654
# Root input [71, 75] [108 112] with score 0.8781
# Root input [71, 73] [108 110] with score 2.2957
# Root input [71, 73] [110 112] with score 1.0446
# Root input [68, 75] [112 120] with score 1.6912
# Root input [71, 75] [112 116] with score 4.5808
# Root input [71, 73] [112 114] with score 1.3879
# Root input [73, 75] [112 114] with score 1.8272
# Root input [73, 75] [114 116] with score 1.3070
# Root input [71, 75] [116 120] with score 0.7932
# Root input [73, 75] [116 118] with score 1.2335
# Root input [75, 100] [60 90] with score 11.4164
# Root input [75, 87] [60 75] with score 3.4970
# Root input [81, 87] [67 75] with score 3.5767
# Root input [81, 84] [71 75] with score 3.6060
# Root input [84, 87] [71 75] with score 1.7731
# Root input [75, 87] [75 90] with score 5.2705
# Root input [81, 87] [75 82] with score 5.8635
# Root input [81, 84] [75 78] with score 1.6188
# Root input [81, 84] [78 82] with score 0.5057
# Root input [84, 87] [75 78] with score 3.7197
# Root input [87, 100] [60 75] with score 0.8637
# Root input [87, 93] [67 75] with score 2.3843
# Root input [87, 90] [71 75] with score 3.7384
# Root input [87, 100] [75 90] with score 4.4020
# Root input [87, 93] [75 82] with score 7.4189
# Root input [87, 90] [75 78] with score 3.1094
# Root input [87, 90] [78 82] with score 4.3213
# Root input [75, 100] [90 120] with score 7.5068
# Root input [75, 87] [90 105] with score 2.6532
# Root input [75, 81] [97 105] with score 3.4786
# Root input [75, 78] [101 105] with score 3.1404
# Root input [78, 81] [101 105] with score 0.9385
# Root input [75, 87] [105 120] with score 8.7499
# Root input [75, 81] [105 112] with score 6.6802
# Root input [75, 78] [105 108] with score 6.1319
# Root input [78, 81] [108 112] with score 2.3970
# Root input [75, 81] [112 120] with score 3.8904
# Root input [75, 78] [112 116] with score 4.6254
# Root input [75, 78] [116 120] with score 1.5083
# Root input [78, 81] [112 116] with score 0.8328
# GradCAM:
# Execution completed in 0.16 s
# GradCAM++:
# Execution completed in 0.20 s
# Gradient Explainer:
# Execution completed in 12.61 s
# Deep Explainer:
# Execution completed in 3.12 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 3.12 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 20.4066
# Root input [25, 50] [0 30] with score 11.0077
# Root input [25, 37] [0 15] with score 8.0787
# Root input [31, 37] [0 7] with score 4.7703
# Root input [31, 34] [0 3] with score 0.5521
# Root input [31, 34] [3 7] with score 0.5450
# Root input [34, 37] [3 7] with score 3.7881
# Root input [31, 37] [7 15] with score 1.3696
# Root input [31, 34] [7 11] with score 3.5649
# Root input [37, 50] [0 15] with score 4.7199
# Root input [37, 43] [0 7] with score 0.5037
# Root input [37, 40] [3 7] with score 0.8357
# Root input [37, 43] [7 15] with score 2.6167
# Root input [37, 40] [7 11] with score 4.7449
# Root input [25, 50] [30 60] with score 12.6940
# Root input [25, 37] [30 45] with score 9.3977
# Root input [31, 37] [30 37] with score 7.1593
# Root input [31, 34] [30 33] with score 1.2428
# Root input [31, 34] [33 37] with score 1.4228
# Root input [34, 37] [33 37] with score 4.0568
# Root input [37, 50] [30 45] with score 5.1009
# Root input [37, 43] [30 37] with score 2.4053
# Root input [37, 40] [30 33] with score 1.1765
# Root input [37, 40] [33 37] with score 1.2783
# Root input [37, 43] [37 45] with score 3.7008
# Root input [37, 40] [37 41] with score 5.2814
# Root input [0, 50] [60 120] with score 31.3558
# Root input [0, 25] [60 90] with score 7.8370
# Root input [12, 25] [75 90] with score 7.7323
# Root input [18, 25] [75 82] with score 1.1281
# Root input [21, 25] [78 82] with score 1.2231
# Root input [21, 23] [80 82] with score 1.1428
# Root input [18, 25] [82 90] with score 6.4219
# Root input [21, 25] [82 86] with score 4.1837
# Root input [21, 23] [82 84] with score 1.2831
# Root input [23, 25] [82 84] with score 1.4005
# Root input [23, 25] [84 86] with score 1.0719
# Root input [21, 25] [86 90] with score 2.6467
# Root input [21, 23] [88 90] with score 2.1841
# Root input [23, 25] [86 88] with score 4.4384
# Root input [0, 25] [90 120] with score 9.6498
# Root input [0, 12] [90 105] with score 5.4436
# Root input [0, 6] [97 105] with score 3.2490
# Root input [0, 3] [101 105] with score 1.3180
# Root input [3, 6] [101 105] with score 2.2282
# Root input [6, 12] [97 105] with score 2.4657
# Root input [6, 9] [101 105] with score 4.0203
# Root input [9, 12] [101 105] with score 1.2165
# Root input [0, 12] [105 120] with score 6.5905
# Root input [0, 6] [105 112] with score 3.1548
# Root input [3, 6] [105 108] with score 1.1169
# Root input [6, 12] [105 112] with score 6.0305
# Root input [6, 9] [105 108] with score 2.4815
# Root input [6, 9] [108 112] with score 1.4081
# Root input [9, 12] [108 112] with score 0.9312
# Root input [25, 50] [60 90] with score 17.4014
# Root input [25, 37] [75 90] with score 10.0267
# Root input [25, 31] [75 82] with score 0.8630
# Root input [28, 31] [78 82] with score 1.4945
# Root input [25, 31] [82 90] with score 10.9582
# Root input [25, 28] [82 86] with score 4.6473
# Root input [25, 28] [86 90] with score 3.5488
# Root input [28, 31] [82 86] with score 0.7626
# Root input [28, 31] [86 90] with score 2.5375
# Root input [37, 50] [60 75] with score 10.0142
# Root input [37, 43] [60 67] with score 1.0894
# Root input [40, 43] [60 63] with score 2.3003
# Root input [37, 43] [67 75] with score 0.8362
# Root input [40, 43] [67 71] with score 2.3980
# Root input [43, 50] [60 67] with score 6.9167
# Root input [43, 46] [63 67] with score 4.1178
# Root input [46, 50] [60 63] with score 0.9195
# Root input [46, 50] [63 67] with score 2.5924
# Root input [46, 48] [63 65] with score 2.4267
# Root input [46, 48] [65 67] with score 1.8726
# Root input [43, 50] [67 75] with score 2.9530
# Root input [43, 46] [67 71] with score 0.9785
# Root input [46, 50] [67 71] with score 3.7686
# Root input [46, 48] [67 69] with score 1.4951
# Root input [48, 50] [67 69] with score 1.0763
# Root input [48, 50] [69 71] with score 1.1189
# Root input [50, 100] [0 60] with score 26.5371
# Root input [75, 100] [0 30] with score 30.2254
# Root input [75, 87] [0 15] with score 5.9549
# Root input [81, 87] [7 15] with score 6.1744
# Root input [81, 84] [11 15] with score 3.9935
# Root input [84, 87] [11 15] with score 2.4675
# Root input [75, 87] [15 30] with score 12.8413
# Root input [81, 87] [15 22] with score 3.6117
# Root input [81, 84] [15 18] with score 1.1597
# Root input [81, 84] [18 22] with score 0.5369
# Root input [84, 87] [15 18] with score 3.6263
# Root input [81, 87] [22 30] with score 8.9831
# Root input [81, 84] [22 26] with score 2.2688
# Root input [81, 84] [26 30] with score 1.4661
# Root input [84, 87] [22 26] with score 4.8854
# Root input [84, 87] [26 30] with score 1.9006
# Root input [87, 100] [0 15] with score 3.4584
# Root input [87, 93] [7 15] with score 7.1604
# Root input [87, 90] [11 15] with score 7.1390
# Root input [87, 100] [15 30] with score 6.9509
# Root input [87, 93] [15 22] with score 5.0160
# Root input [87, 90] [15 18] with score 2.3283
# Root input [87, 90] [18 22] with score 2.4840
# Root input [87, 93] [22 30] with score 5.9128
# Root input [87, 90] [22 26] with score 3.6471
# Root input [87, 90] [26 30] with score 5.1832
# Root input [50, 100] [60 120] with score 7.1122
# Root input [50, 75] [90 120] with score 10.0883
# Root input [62, 75] [90 105] with score 10.2276
# Root input [62, 68] [90 97] with score 6.9941
# Root input [62, 65] [90 93] with score 0.6549
# Root input [62, 65] [93 97] with score 3.1726
# Root input [65, 68] [93 97] with score 3.7490
# Root input [62, 68] [97 105] with score 1.7290
# Root input [62, 65] [97 101] with score 1.6410
# Root input [65, 68] [97 101] with score 0.7582
# Root input [68, 75] [90 97] with score 0.8966
# Root input [68, 71] [90 93] with score 1.2198
# Root input [68, 75] [97 105] with score 0.6555
# Root input [68, 71] [97 101] with score 0.5543
# GradCAM:
# Execution completed in 0.15 s
# GradCAM++:
# Execution completed in 0.20 s
# Gradient Explainer:
# Execution completed in 13.59 s
# Deep Explainer:
# Execution completed in 2.52 s
# Kernel Explainer:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Execution completed in 2.52 s
# Hierarchical Explainer:
# Initialized explainer with map size (100, 100)
# Root input [0, 100] [0 120] with score 1.0000
# Root input [0, 50] [0 60] with score 33.5201
# Root input [0, 25] [0 30] with score 17.7862
# Root input [0, 12] [0 15] with score 1.3968
# Root input [6, 12] [7 15] with score 1.7702
# Root input [9, 12] [11 15] with score 1.8028
# Root input [0, 12] [15 30] with score 1.2665
# Root input [6, 12] [15 22] with score 1.2539
# Root input [9, 12] [18 22] with score 1.8621
# Root input [6, 12] [22 30] with score 0.7892
# Root input [9, 12] [22 26] with score 1.6918
# Root input [12, 25] [0 15] with score 7.0281
# Root input [12, 18] [7 15] with score 6.9675
# Root input [12, 15] [11 15] with score 5.0578
# Root input [15, 18] [11 15] with score 2.0490
# Root input [12, 25] [15 30] with score 6.7969
# Root input [12, 18] [15 22] with score 8.8753
# Root input [12, 15] [15 18] with score 2.2913
# Root input [12, 15] [18 22] with score 0.7523
# Root input [15, 18] [15 18] with score 4.9857
# Root input [0, 25] [30 60] with score 16.8740
# Root input [0, 12] [30 45] with score 1.1402
# Root input [6, 12] [37 45] with score 1.6054
# Root input [9, 12] [41 45] with score 1.5091
# Root input [0, 12] [45 60] with score 0.8416
# Root input [6, 12] [45 52] with score 1.2667
# Root input [9, 12] [48 52] with score 1.3198
# Root input [12, 25] [30 45] with score 7.5634
# Root input [12, 18] [37 45] with score 7.2211
# Root input [12, 15] [41 45] with score 5.0948
# Root input [15, 18] [41 45] with score 1.8966
# Root input [18, 25] [37 45] with score 1.1630
# Root input [18, 21] [41 45] with score 2.5478
# Root input [12, 25] [45 60] with score 9.0401
# Root input [12, 18] [45 52] with score 9.2064
# Root input [12, 15] [45 48] with score 2.5791
# Root input [12, 15] [48 52] with score 0.9561
# Root input [15, 18] [45 48] with score 5.9803
# Root input [18, 25] [45 52] with score 2.6999
# Root input [18, 21] [48 52] with score 3.7910
# Root input [0, 50] [60 120] with score 19.4561
# Root input [25, 50] [60 90] with score 21.2262
# Root input [25, 37] [75 90] with score 8.0946
# Root input [31, 37] [82 90] with score 8.1758
# Root input [31, 34] [82 86] with score 2.3705
# Root input [31, 34] [86 90] with score 1.0364
# Root input [34, 37] [82 86] with score 3.1152
# Root input [34, 37] [86 90] with score 1.6323
# Root input [37, 50] [60 75] with score 0.5315
# Root input [37, 43] [60 67] with score 0.7346
# Root input [37, 50] [75 90] with score 12.5498
# Root input [37, 43] [75 82] with score 0.9120
# Root input [40, 43] [78 82] with score 0.8679
# Root input [37, 43] [82 90] with score 4.2491
# Root input [37, 40] [86 90] with score 1.6730
# Root input [40, 43] [82 86] with score 0.5636
# Root input [40, 43] [86 90] with score 0.7167
# Root input [43, 50] [75 82] with score 0.5857
# Root input [46, 50] [78 82] with score 1.1722
# Root input [48, 50] [80 82] with score 1.1491
# Root input [43, 50] [82 90] with score 9.8937
# Root input [43, 46] [82 86] with score 4.5323
# Root input [43, 46] [86 90] with score 1.9959
# Root input [46, 50] [82 86] with score 2.3795
# Root input [46, 48] [82 84] with score 1.5034
# Root input [46, 48] [84 86] with score 1.5697
# Root input [48, 50] [82 84] with score 0.8204
# Root input [46, 50] [86 90] with score 4.0509
# Root input [46, 48] [86 88] with score 4.4582
# Root input [48, 50] [88 90] with score 2.5116
# GradCAM:
# Execution completed in 0.15 s
# GradCAM++:
# Execution completed in 0.20 s
